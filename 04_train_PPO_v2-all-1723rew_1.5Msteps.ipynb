# %% [markdown]
# This experiment, higher learning rate. Larger rollouts.

# %%
import deep_rl

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import torch
from torch.nn import functional as F
from torch.autograd import Variable
from torch import nn, optim
import torch.utils.data

# load as dask array
import time

import logging
import sys
import os
import glob
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook as tqdm

# %%
from deep_rl.utils import Config
from deep_rl.utils.logger import get_logger, get_default_log_dir

from deep_rl.network.network_heads import CategoricalActorCriticNet, QuantileNet, OptionCriticNet, DeterministicActorCriticNet, GaussianActorCriticNet
from deep_rl.network.network_bodies import FCBody

from deep_rl.component.task import ParallelizedTask

# %%
from world_models_sonic.models.vae import VAE5, loss_function_vae
from world_models_sonic.helpers.summarize import TorchSummarizeDf
from world_models_sonic.helpers.dataset import load_cache_data
from world_models_sonic.models.rnn import MDNRNN2
from world_models_sonic.models.inverse_model import InverseModel
from world_models_sonic.models.world_model import WorldModel
from world_models_sonic.custom_envs.env import make_env
from world_models_sonic.custom_envs.wrappers import RandomGameReset
from world_models_sonic import config
from world_models_sonic.helpers.deep_rl import PPOAgent, run_iterations, SonicWorldModelDeepRL, CategoricalWorldActorCriticNet
# Out:
# Importing 0 potential games...
# Imported 0 games
# /home/wassname/.pyenv/versions/3.5.3/envs/jupyter3/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Init

# %%
cuda = torch.cuda.is_available()
env_name = 'sonic256'
z_dim = 512  # latent dimensions

# RNN
action_dim = 10
image_size = 256

verbose = True  # Set this true to render (and make it go slower)

# NAME ='RNN_v3b_256im_512z_1512_v5_greenfield'
NAME = 'RNN_v3b_256im_512z_1512_v6c_VAE5_all'
ppo_save_file = './outputs/models/PPO_512z_all_c.pkl'


save_file_rnn = './outputs/{NAME}/mdnrnn_state_dict.pkl'.format(NAME=NAME)
save_file_vae = './outputs/{NAME}/vae_state_dict.pkl'.format(NAME=NAME)
save_file_finv = './outputs/{NAME}/finv_state_dict.pkl'.format(NAME=NAME)

if not os.path.isdir('./outputs/{NAME}'.format(NAME=NAME)):
    os.makedirs('./outputs/{NAME}'.format(NAME=NAME))

# Log to file and stream
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logger = logging.getLogger(NAME)

# %% [markdown]
# # World model

# %%
# Load VAE
# TODO swap z and k dim, since it's inconsistent with other models
vae = VAE5(image_size=image_size, z_dim=128, conv_dim=64, code_dim=8, k_dim=z_dim)
if cuda:
    vae.cuda()
    
# # Resume    
if os.path.isfile(save_file_vae):
    state_dict = torch.load(save_file_vae)
    vae.load_state_dict(state_dict)
    print('loaded save_file {save_file}'.format(save_file=save_file_vae))
    
# Load MDRNN
action_dim, hidden_size, n_mixture, temp = action_dim, 512, 2, 0.0

mdnrnn = MDNRNN2(z_dim, action_dim, hidden_size, n_mixture, temp)
if cuda:
    mdnrnn = mdnrnn.cuda()
state_dict = torch.load(save_file_rnn)
mdnrnn.load_state_dict(state_dict)
print('loaded {save_file}'.format(save_file=save_file_rnn))
    
finv = InverseModel(z_dim, action_dim, hidden_size=256)
if cuda:
    finv = finv.cuda()
state_dict = torch.load(save_file_finv)
finv.load_state_dict(state_dict)
print('loaded {save_file}'.format(save_file=save_file_finv))
    
world_model = WorldModel(vae, mdnrnn, finv)
world_model = world_model.eval() # Samples without randomness
if cuda:
    world_model = world_model.cuda()
# Out:
# loaded save_file ./outputs/RNN_v3b_256im_512z_1512_v6c_VAE5_all/vae_state_dict.pkl
# loaded ./outputs/RNN_v3b_256im_512z_1512_v6c_VAE5_all/mdnrnn_state_dict.pkl
# loaded ./outputs/RNN_v3b_256im_512z_1512_v6c_VAE5_all/finv_state_dict.pkl

# %% [markdown]
# # summarize

# %%
from IPython.display import display

with torch.no_grad():
    img = np.random.randn(image_size, image_size, 3)
    action = np.array(np.random.randint(0,action_dim))[np.newaxis]
    action = Variable(torch.from_numpy(action)).float().cuda()[np.newaxis]
    gpu_img = Variable(torch.from_numpy(img[np.newaxis].transpose(0, 3, 1, 2))).float().cuda()
    if cuda:
        gpu_img = gpu_img.cuda()
    with TorchSummarizeDf(vae) as tdf:
        x, mu_vae, logvar_vae = vae.forward(gpu_img)
        z = vae.sample(mu_vae, logvar_vae)
        df_vae = tdf.make_df()

    display(df_vae[df_vae.level<2])
    
    with TorchSummarizeDf(mdnrnn) as tdf: 
        pi, mu, sigma, hidden_state = mdnrnn.forward(z.unsqueeze(1).repeat((1,2,1)))
        z_next = mdnrnn.sample(pi, mu, sigma)
        df_mdnrnn = tdf.make_df()
    
    display(df_mdnrnn)
    

    with TorchSummarizeDf(finv) as tdf:
        finv(z.repeat((1,2,1)), z_next)   
        df_finv = tdf.make_df()
    display(df_finv)

    with TorchSummarizeDf(world_model) as tdf:
        world_model(gpu_img, action)
        df_world_model = tdf.make_df()
    display(df_world_model[df_world_model.level<2])
    
    del img, action, gpu_img, x, mu, z, z_next, mu_vae, pi, sigma, logvar_vae
# Out:
# Total parameters 21877123
# Total trainable parameters 21877123
#          name    class_name            input_shape           output_shape  \
# 4   encoder.0    ConvBlock4    [(-1, 3, 256, 256)]   [(-1, 64, 256, 256)]
# 8   encoder.1    ConvBlock4   [(-1, 64, 256, 256)]  [(-1, 128, 128, 128)]
# 12  encoder.2    ConvBlock4  [(-1, 128, 128, 128)]    [(-1, 192, 64, 64)]
# 16  encoder.3    ConvBlock4    [(-1, 192, 64, 64)]    [(-1, 256, 32, 32)]
# 20  encoder.4    ConvBlock4    [(-1, 256, 32, 32)]    [(-1, 320, 16, 16)]
# 24  encoder.5    ConvBlock4    [(-1, 320, 16, 16)]      [(-1, 384, 8, 8)]
# 25  encoder.6        Conv2d      [(-1, 384, 8, 8)]      [(-1, 128, 8, 8)]
# 26         mu        Linear           [(-1, 8192)]            [(-1, 512)]
# 27     logvar        Linear           [(-1, 8192)]            [(-1, 512)]
# 28          z        Linear            [(-1, 512)]           [(-1, 8192)]
# 32  decoder.0  DeconvBlock4      [(-1, 128, 8, 8)]      [(-1, 384, 8, 8)]
# 36  decoder.1  DeconvBlock4      [(-1, 384, 8, 8)]    [(-1, 320, 16, 16)]
# 40  decoder.2  DeconvBlock4    [(-1, 320, 16, 16)]    [(-1, 256, 32, 32)]
# 44  decoder.3  DeconvBlock4    [(-1, 256, 32, 32)]    [(-1, 192, 64, 64)]
# 48  decoder.4  DeconvBlock4    [(-1, 192, 64, 64)]  [(-1, 128, 128, 128)]
# 52  decoder.5  DeconvBlock4  [(-1, 128, 128, 128)]   [(-1, 64, 256, 256)]
# 53  decoder.6        Conv2d   [(-1, 64, 256, 256)]    [(-1, 3, 256, 256)]
# 54    sigmoid       Sigmoid    [(-1, 3, 256, 256)]    [(-1, 3, 256, 256)]
#
#     nb_params  level
# 4        1920      1
# 8      131456      1
# 12     393792      1
# 16     787200      1
# 20    1311680      1
# 24    1967232      1
# 25      49280      1
# 26    4194816      0
# 27    4194816      0
# 28    4202496      0
# 32      50304      1
# 36    1967040      1
# 40    1311488      1
# 44     787008      1
# 48     393600      1
# 52     131264      1
# 53       1731      1
# 54          0      0
# Total parameters 11565056
# Total trainable parameters 11565056
#   name class_name                                        input_shape  \
# 1  rnn       LSTM  [[(-1, 2, 522)], [[(-1, 1, 512)], [(-1, 1, 512...
# 2  ln1     Linear                             [(-1, 512), (-1, 512)]
# 3  ln2     Linear                             [(-1, 512), (-1, 512)]
# 4  mdn     Linear                           [(-1, 2560), (-1, 2560)]
#
#                                         output_shape  nb_params  level
# 1  [[(-1, 2, 512)], [[(-1, 1, 512)], [(-1, 1, 512...    2121728      0
# 2                             [(-1, 512), (-1, 512)]     262656      0
# 3                           [(-1, 2560), (-1, 2560)]    1313280      0
# 4                           [(-1, 3072), (-1, 3072)]    7867392      0
# Total parameters 330762
# Total trainable parameters 330762
#   name class_name      input_shape    output_shape  nb_params  level
# 1  ln1     Linear  [(-1, 2, 1024)]  [(-1, 2, 256)]     262400      0
# 2  ln2     Linear   [(-1, 2, 256)]  [(-1, 2, 256)]      65792      0
# 3  ln3     Linear   [(-1, 2, 256)]   [(-1, 2, 10)]       2570      0
# Total parameters 33772941
# Total trainable parameters 33772941
#            name class_name                                        input_shape  \
# 26       vae.mu     Linear                                       [(-1, 8192)]
# 27   vae.logvar     Linear                                       [(-1, 8192)]
# 28        vae.z     Linear                                        [(-1, 512)]
# 54  vae.sigmoid    Sigmoid                                [(-1, 3, 256, 256)]
# 55   mdnrnn.rnn       LSTM  [[(-1, 1, 522)], [[(-1, 1, 512)], [(-1, 1, 512...
# 56   mdnrnn.ln1     Linear                                        [(-1, 512)]
# 57   mdnrnn.ln2     Linear                                        [(-1, 512)]
# 58   mdnrnn.mdn     Linear                                       [(-1, 2560)]
#
#                                          output_shape  nb_params  level
# 26                                        [(-1, 512)]    4194816      1
# 27                                        [(-1, 512)]    4194816      1
# 28                                       [(-1, 8192)]    4202496      1
# 54                                [(-1, 3, 256, 256)]          0      1
# 55  [[(-1, 1, 512)], [[(-1, 1, 512)], [(-1, 1, 512...    2121728      1
# 56                                        [(-1, 512)]     262656      1
# 57                                       [(-1, 2560)]    1313280      1
# 58                                       [(-1, 3072)]    7867392      1

# %% [markdown]
# # Train

# %%
log_dir = log_dir='./outputs/{NAME}'.format(NAME=NAME)
z_state_dim=world_model.mdnrnn.z_dim + world_model.mdnrnn.hidden_size
print(log_dir)


def task_fn(log_dir):
    return SonicWorldModelDeepRL(
        env_fn=lambda: RandomGameReset(make_env(
            'sonic256')),
        max_steps=4000,
        log_dir=log_dir,
        verbose=verbose
    )


config = Config()

config.num_workers = 1
config.task_fn = lambda: ParallelizedTask(
    task_fn, config.num_workers, single_process=config.num_workers == 1)
config.optimizer_fn = lambda params: torch.optim.Adam(params, 3e-4, eps=1e-5)
config.network_fn = lambda state_dim, action_dim: CategoricalWorldActorCriticNet(
    state_dim, action_dim, FCBody(z_state_dim, hidden_units=(64, 64), gate=F.relu), gpu=0 if cuda else -1, world_model_fn=lambda: world_model,
    render=(config.num_workers==1 and verbose),
    z_shape=(32, 16)
)
config.discount = 0.99
config.logger = get_logger(
    NAME,
    file_name='deep_rl_ppo.log',
    level=logging.INFO,
    log_dir='./outputs/{NAME}'.format(NAME=NAME), )
config.use_gae = True
config.gae_tau = 0.95
config.entropy_weight = 0.001
config.gradient_clip = 0.5
config.rollout_length = 512
config.optimization_epochs = 10
config.num_mini_batches = 32
config.ppo_ratio_clip = 0.3
config.iteration_log_interval = 10
agent = PPOAgent(config)
if os.path.isfile(ppo_save_file):
    print('loading', ppo_save_file, 'modified', time.ctime(os.path.getmtime(ppo_save_file)))
    agent.load(ppo_save_file)
else:
    print("couldn't find save")

# ppo_checkpoint_file = '%s/%s-%s-model-%s.pkl' % (log_dir, agent.__class__.__name__, config.tag, agent.task.name)
# if os.path.isfile(ppo_checkpoint_file):
#     print('loading ppo_checkpoint_file', ppo_checkpoint_file, 'modified', time.ctime(os.path.getmtime(ppo_checkpoint_file)))
#     agent.load(ppo_checkpoint_file)
# else:
#     print("couldn't find checkpoint")
# Out:
# ./outputs/RNN_v3b_256im_512z_1512_v6c_VAE5_all
# game: SonicAndKnuckles3-Genesis state: LaunchBaseZone.Act2
# game: SonicTheHedgehog2-Genesis state: MysticCaveZone.Act1
# reseting to AngelIslandZone.Act1.state
# reseting to WingFortressZone.state
# loading ./outputs/models/PPO_512z_all_c.pkl modified Fri May 25 21:09:35 2018
# reseting to WingFortressZone.state
# reseting to WingFortressZone.state
# reseting to OilOceanZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to WingFortressZone.state
# reseting to WingFortressZone.state
# reseting to LavaReefZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to MushroomHillZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to IcecapZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to IcecapZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to HiddenPalaceZone.state
# reseting to MetropolisZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to HiddenPalaceZone.state
# reseting to MetropolisZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to WingFortressZone.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to CarnivalNightZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to OilOceanZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to MushroomHillZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to HiddenPalaceZone.state
# reseting to EmeraldHillZone.Act1.state
# reseting to AngelIslandZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to WingFortressZone.state
# reseting to EmeraldHillZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to MushroomHillZone.Act1.state
# reseting to WingFortressZone.state
# reseting to IcecapZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to DeathEggZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to DeathEggZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to IcecapZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to MarbleGardenZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to HiddenPalaceZone.state
# reseting to HydrocityZone.Act2.state
# reseting to IcecapZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to DeathEggZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to DeathEggZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to WingFortressZone.state
# reseting to MarbleGardenZone.Act2.state
# reseting to WingFortressZone.state
# reseting to CasinoNightZone.Act1.state
# reseting to MarbleGardenZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to SandopolisZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to IcecapZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to OilOceanZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to IcecapZone.Act1.state
# reseting to OilOceanZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to WingFortressZone.state
# reseting to CarnivalNightZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to SandopolisZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to CarnivalNightZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to DeathEggZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to AngelIslandZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to IcecapZone.Act2.state
# reseting to WingFortressZone.state
# reseting to HydrocityZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to IcecapZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to IcecapZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to OilOceanZone.Act1.state
# reseting to WingFortressZone.state
# reseting to IcecapZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to WingFortressZone.state
# reseting to MushroomHillZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to MushroomHillZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to HiddenPalaceZone.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to CarnivalNightZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to AngelIslandZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to MarbleGardenZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to IcecapZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to WingFortressZone.state
# reseting to WingFortressZone.state
# reseting to MetropolisZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to IcecapZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to MetropolisZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to AngelIslandZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LaunchBaseZone.Act2.state
# reseting to HiddenPalaceZone.state
# reseting to LaunchBaseZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to WingFortressZone.state
# reseting to MetropolisZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to WingFortressZone.state
# reseting to AquaticRuinZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to HiddenPalaceZone.state
# reseting to EmeraldHillZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to WingFortressZone.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to WingFortressZone.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to SandopolisZone.Act1.state
# reseting to HiddenPalaceZone.state
# reseting to MushroomHillZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to HydrocityZone.Act2.state
# reseting to MetropolisZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to DeathEggZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to CarnivalNightZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to MushroomHillZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to MarbleGardenZone.Act2.state
# reseting to MetropolisZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to IcecapZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to HiddenPalaceZone.state
# reseting to HillTopZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to MetropolisZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to AngelIslandZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to HydrocityZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to WingFortressZone.state
# reseting to LavaReefZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to AngelIslandZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to DeathEggZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to WingFortressZone.state
# reseting to WingFortressZone.state
# reseting to LavaReefZone.Act2.state
# reseting to HydrocityZone.Act2.state
# reseting to SandopolisZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to IcecapZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to DeathEggZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LaunchBaseZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to MarbleGardenZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to HydrocityZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to WingFortressZone.state
# reseting to SandopolisZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to MushroomHillZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to WingFortressZone.state
# reseting to OilOceanZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to DeathEggZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to DeathEggZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to LaunchBaseZone.Act2.state
# reseting to LavaReefZone.Act2.state
# reseting to MushroomHillZone.Act2.state
# reseting to MetropolisZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to SandopolisZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to MetropolisZone.Act1.state
# reseting to SandopolisZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to HydrocityZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to HiddenPalaceZone.state
# reseting to MetropolisZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to OilOceanZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to EmeraldHillZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to AngelIslandZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to HiddenPalaceZone.state
# reseting to AngelIslandZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to WingFortressZone.state
# reseting to AquaticRuinZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to MushroomHillZone.Act1.state
# reseting to AquaticRuinZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to AquaticRuinZone.Act2.state
# reseting to MushroomHillZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to OilOceanZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to WingFortressZone.state
# reseting to MushroomHillZone.Act1.state
# reseting to CasinoNightZone.Act1.state
# reseting to LaunchBaseZone.Act2.state
# reseting to MarbleGardenZone.Act2.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to HydrocityZone.Act2.state
# reseting to LaunchBaseZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to MarbleGardenZone.Act1.state
# reseting to MetropolisZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to MetropolisZone.Act2.state
# reseting to OilOceanZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to HydrocityZone.Act2.state
# reseting to WingFortressZone.state
# reseting to CarnivalNightZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to EmeraldHillZone.Act2.state
# reseting to IcecapZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to FlyingBatteryZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to HillTopZone.Act1.state
# reseting to MysticCaveZone.Act2.state
# reseting to MysticCaveZone.Act2.state
# reseting to EmeraldHillZone.Act2.state
# reseting to SandopolisZone.Act1.state
# reseting to DeathEggZone.Act1.state
# reseting to OilOceanZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to MushroomHillZone.Act2.state
# reseting to MysticCaveZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to HillTopZone.Act1.state
# reseting to OilOceanZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to CarnivalNightZone.Act1.state
# reseting to MarbleGardenZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to LaunchBaseZone.Act1.state
# reseting to EmeraldHillZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to MarbleGardenZone.Act2.state
# reseting to AquaticRuinZone.Act1.state
# reseting to LavaReefZone.Act2.state
# reseting to IcecapZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to CarnivalNightZone.Act2.state
# reseting to WingFortressZone.state
# reseting to MetropolisZone.Act1.state
# reseting to AngelIslandZone.Act1.state
# reseting to AquaticRuinZone.Act2.state
# reseting to CasinoNightZone.Act1.state
# reseting to AngelIslandZone.Act1.state
# reseting to ChemicalPlantZone.Act1.state
# reseting to SandopolisZone.Act1.state
# reseting to MysticCaveZone.Act1.state
# reseting to DeathEggZone.Act2.state
# reseting to LaunchBaseZone.Act2.state
# reseting to SandopolisZone.Act2.state
# reseting to LaunchBaseZone.Act1.state
# reseting to ChemicalPlantZone.Act2.state
# reseting to CarnivalNightZone.Act2.state
# Process ProcessWrapper-1:
# Process ProcessWrapper-2:
# Traceback (most recent call last):
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
try:
    run_iterations(agent, log_dir=log_dir)
except:
    if config.num_workers==1:
        agent.task.tasks[0].env.close()
    else:
        [t.close() for t in agent.task.tasks]
    print("saving", ppo_save_file)
    agent.save(ppo_save_file)
    raise
# Out:
# 2018-05-25 21:13:23,623 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1024, min/mean/max reward 0.0000/0.6750/1.3500 of 2
# 2018-05-25 21:13:23,624 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/0.6750/0.6750 of 1 14.6599 s/rollout
# 2018-05-25 21:18:08,745 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 11264, min/mean/max reward 1.8509/10.4010/18.9510 of 2
# 2018-05-25 21:18:08,746 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/8.4259/16.1538 of 11 14.2928 s/rollout
# 2018-05-25 21:22:48,856 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 21504, min/mean/max reward 4.6975/15.6533/26.6091 of 2
# 2018-05-25 21:22:48,857 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/9.9723/16.1538 of 21 14.1560 s/rollout
# 2018-05-25 21:27:32,763 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 31744, min/mean/max reward 5.9409/7.4569/8.9728 of 2
# 2018-05-25 21:27:32,765 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/9.7104/16.1538 of 31 14.1687 s/rollout
# 2018-05-25 21:32:12,228 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 41984, min/mean/max reward 4.1380/8.8150/13.4919 of 2
# 2018-05-25 21:32:12,230 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/9.6979/16.1538 of 41 14.1210 s/rollout
# 2018-05-25 21:36:54,738 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 52224, min/mean/max reward 6.4464/8.4746/10.5028 of 2
# 2018-05-25 21:36:54,740 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/9.5058/16.1538 of 51 14.1219 s/rollout
# 2018-05-25 21:41:25,645 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 62464, min/mean/max reward 10.4592/18.1709/25.8826 of 2
# 2018-05-25 21:41:25,646 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/10.5385/31.8733 of 61 14.0274 s/rollout
# 2018-05-25 21:45:47,039 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 72704, min/mean/max reward 5.7291/50.8165/95.9039 of 2
# 2018-05-25 21:45:47,040 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/12.0199/50.8165 of 71 13.8925 s/rollout
# 2018-05-25 21:50:08,336 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 82944, min/mean/max reward 17.1130/28.5609/40.0088 of 2
# 2018-05-25 21:50:08,337 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/16.0176/56.5085 of 81 13.7903 s/rollout
# 2018-05-25 21:54:29,018 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 93184, min/mean/max reward 0.9562/14.7507/28.5453 of 2
# 2018-05-25 21:54:29,019 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/16.8938/56.5085 of 91 13.7072 s/rollout
# 2018-05-25 21:58:49,800 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 103424, min/mean/max reward 16.9103/19.2974/21.6845 of 2
# 2018-05-25 21:58:49,802 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 0.6750/16.7109/56.5085 of 100 13.6309 s/rollout
# 2018-05-25 22:03:10,231 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 113664, min/mean/max reward 4.4901/5.8139/7.1377 of 2
# 2018-05-25 22:03:10,232 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/17.3941/56.5085 of 100 13.5074 s/rollout
# 2018-05-25 22:07:31,139 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 123904, min/mean/max reward 12.7444/12.8836/13.0228 of 2
# 2018-05-25 22:07:31,140 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/17.6785/56.5085 of 100 13.4114 s/rollout
# 2018-05-25 22:11:52,261 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 134144, min/mean/max reward 1.4366/6.2798/11.1231 of 2
# 2018-05-25 22:11:52,263 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/18.0655/56.5085 of 100 13.2975 s/rollout
# 2018-05-25 22:16:13,788 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 144384, min/mean/max reward 28.0844/35.6186/43.1529 of 2
# 2018-05-25 22:16:13,789 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/18.5293/56.5085 of 100 13.2078 s/rollout
# 2018-05-25 22:20:35,278 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 154624, min/mean/max reward 17.7078/23.4280/29.1481 of 2
# 2018-05-25 22:20:35,279 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/20.2990/56.5085 of 100 13.1027 s/rollout
# 2018-05-25 22:24:56,483 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 164864, min/mean/max reward 1.4366/20.7754/40.1142 of 2
# 2018-05-25 22:24:56,484 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/20.7376/56.5085 of 100 13.0542 s/rollout
# 2018-05-25 22:29:17,615 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 175104, min/mean/max reward 5.9260/11.6706/17.4152 of 2
# 2018-05-25 22:29:17,616 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/20.5850/56.5085 of 100 13.0529 s/rollout
# 2018-05-25 22:33:38,293 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 185344, min/mean/max reward 6.4060/6.9663/7.5266 of 2
# 2018-05-25 22:33:38,294 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/16.9503/38.4216 of 100 13.0498 s/rollout
# 2018-05-25 22:37:59,479 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 195584, min/mean/max reward 5.4693/17.0073/28.5453 of 2
# 2018-05-25 22:37:59,480 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.0254/15.6087/35.6186 of 100 13.0523 s/rollout
# 2018-05-25 22:42:21,213 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 205824, min/mean/max reward 6.2913/29.7927/53.2941 of 2
# 2018-05-25 22:42:21,214 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.6300/16.4474/35.6186 of 100 13.0571 s/rollout
# 2018-05-25 22:46:42,689 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 216064, min/mean/max reward 5.4448/11.8505/18.2562 of 2
# 2018-05-25 22:46:42,691 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.6300/16.6780/35.7751 of 100 13.0623 s/rollout
# 2018-05-25 22:51:03,720 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 226304, min/mean/max reward 4.4549/15.9407/27.4264 of 2
# 2018-05-25 22:51:03,721 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.6300/15.9534/35.7751 of 100 13.0629 s/rollout
# 2018-05-25 22:55:25,585 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 236544, min/mean/max reward 6.9652/12.7019/18.4386 of 2
# 2018-05-25 22:55:25,587 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.6300/16.4775/35.7751 of 100 13.0666 s/rollout
# 2018-05-25 22:59:45,942 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 246784, min/mean/max reward 6.1529/6.2431/6.3332 of 2
# 2018-05-25 22:59:45,943 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.6300/17.6232/35.7751 of 100 13.0608 s/rollout
# 2018-05-25 23:04:07,478 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 257024, min/mean/max reward 3.5578/7.2395/10.9213 of 2
# 2018-05-25 23:04:07,479 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/15.5320/35.7751 of 100 13.0610 s/rollout
# 2018-05-25 23:08:28,349 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 267264, min/mean/max reward 6.5418/8.6527/10.7636 of 2
# 2018-05-25 23:08:28,351 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/14.8135/35.7751 of 100 13.0593 s/rollout
# 2018-05-25 23:12:49,739 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 277504, min/mean/max reward 4.8932/12.0647/19.2363 of 2
# 2018-05-25 23:12:49,740 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/13.9700/35.7751 of 100 13.0606 s/rollout
# 2018-05-25 23:17:11,061 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 287744, min/mean/max reward 4.9586/12.1786/19.3985 of 2
# 2018-05-25 23:17:11,062 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/14.2991/35.7751 of 100 13.0638 s/rollout
# 2018-05-25 23:21:35,411 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 297984, min/mean/max reward 16.2402/21.6942/27.1483 of 2
# 2018-05-25 23:21:35,412 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/14.8894/35.7751 of 100 13.0797 s/rollout
# 2018-05-25 23:26:10,907 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 308224, min/mean/max reward 19.4836/23.6183/27.7530 of 2
# 2018-05-25 23:26:10,909 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/14.9821/35.7751 of 100 13.1485 s/rollout
# 2018-05-25 23:30:45,352 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 318464, min/mean/max reward 6.0592/11.5861/17.1130 of 2
# 2018-05-25 23:30:45,354 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/15.1579/30.1297 of 100 13.2133 s/rollout
# 2018-05-25 23:35:20,902 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 328704, min/mean/max reward 4.0285/13.9563/23.8842 of 2
# 2018-05-25 23:35:20,904 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/15.6154/30.1297 of 100 13.2859 s/rollout
# 2018-05-25 23:39:54,383 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 338944, min/mean/max reward 5.1548/16.1026/27.0504 of 2
# 2018-05-25 23:39:54,385 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/15.2652/30.1297 of 100 13.3440 s/rollout
# 2018-05-25 23:44:29,546 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 349184, min/mean/max reward 6.5656/11.8437/17.1219 of 2
# 2018-05-25 23:44:29,548 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 3.1768/13.9297/28.9515 of 100 13.4180 s/rollout
# 2018-05-25 23:49:02,919 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 359424, min/mean/max reward 29.0632/41.1753/53.2874 of 2
# 2018-05-25 23:49:02,921 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.9910/15.1830/41.1753 of 100 13.4772 s/rollout
# 2018-05-25 23:53:35,130 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 369664, min/mean/max reward 4.9788/13.8920/22.8051 of 2
# 2018-05-25 23:53:35,131 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.9910/17.3627/41.1753 of 100 13.5339 s/rollout
# 2018-05-25 23:57:56,407 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 379904, min/mean/max reward 4.2529/6.3819/8.5109 of 2
# 2018-05-25 23:57:56,408 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.9910/17.3772/41.1753 of 100 13.5333 s/rollout
# 2018-05-26 00:02:17,520 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 390144, min/mean/max reward 5.4664/13.3229/21.1794 of 2
# 2018-05-26 00:02:17,521 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.8596/17.1975/41.1753 of 100 13.5323 s/rollout
# 2018-05-26 00:06:38,467 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 400384, min/mean/max reward 1.4366/8.9265/16.4165 of 2
# 2018-05-26 00:06:38,469 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.8596/16.7278/41.1753 of 100 13.5153 s/rollout
# 2018-05-26 00:10:58,249 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 410624, min/mean/max reward 6.9065/31.3869/55.8672 of 2
# 2018-05-26 00:10:58,251 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/16.9244/41.1753 of 100 13.4367 s/rollout
# 2018-05-26 00:15:19,069 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 420864, min/mean/max reward 20.5968/23.8725/27.1483 of 2
# 2018-05-26 00:15:19,070 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/16.7977/41.1753 of 100 13.3686 s/rollout
# 2018-05-26 00:19:40,189 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 431104, min/mean/max reward 9.3522/9.8520/10.3519 of 2
# 2018-05-26 00:19:40,190 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/17.3833/41.1753 of 100 13.2964 s/rollout
# 2018-05-26 00:24:00,961 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 441344, min/mean/max reward 6.7069/11.9100/17.1130 of 2
# 2018-05-26 00:24:00,962 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/17.0138/41.1753 of 100 13.2329 s/rollout
# 2018-05-26 00:28:21,905 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 451584, min/mean/max reward 3.0566/26.7358/50.4151 of 2
# 2018-05-26 00:28:21,907 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/18.0464/41.1753 of 100 13.1618 s/rollout
# 2018-05-26 00:32:42,001 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 461824, min/mean/max reward 6.4904/16.8193/27.1483 of 2
# 2018-05-26 00:32:42,002 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/17.5936/40.5131 of 100 13.0954 s/rollout
# 2018-05-26 00:37:02,951 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 472064, min/mean/max reward 16.6634/32.9956/49.3277 of 2
# 2018-05-26 00:37:02,952 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/16.9187/39.5745 of 100 13.0391 s/rollout
# 2018-05-26 00:41:23,145 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 482304, min/mean/max reward 14.3519/25.1452/35.9384 of 2
# 2018-05-26 00:41:23,146 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/18.3306/39.5745 of 100 13.0337 s/rollout
# 2018-05-26 00:45:43,135 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 492544, min/mean/max reward 10.2228/14.2949/18.3670 of 2
# 2018-05-26 00:45:43,136 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/18.7336/39.5745 of 100 13.0281 s/rollout
# 2018-05-26 00:50:04,053 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 502784, min/mean/max reward 1.0619/11.5837/22.1054 of 2
# 2018-05-26 00:50:04,054 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.1715/18.9385/39.5745 of 100 13.0279 s/rollout
# 2018-05-26 00:54:25,091 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 513024, min/mean/max reward 0.8944/5.8872/10.8799 of 2
# 2018-05-26 00:54:25,092 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.9780/17.4426/39.5745 of 100 13.0342 s/rollout
# 2018-05-26 00:58:45,820 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 523264, min/mean/max reward 8.9295/31.1085/53.2874 of 2
# 2018-05-26 00:58:45,821 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/17.6322/39.5745 of 100 13.0338 s/rollout
# 2018-05-26 01:03:12,048 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 533504, min/mean/max reward 32.9656/43.1265/53.2874 of 2
# 2018-05-26 01:03:12,049 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/19.5305/43.1265 of 100 13.0593 s/rollout
# 2018-05-26 01:07:39,868 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 543744, min/mean/max reward 19.5269/24.6771/29.8274 of 2
# 2018-05-26 01:07:39,869 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/21.2597/43.1265 of 100 13.0945 s/rollout
# 2018-05-26 01:12:08,451 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 553984, min/mean/max reward 6.8769/13.4725/20.0681 of 2
# 2018-05-26 01:12:08,463 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/20.4463/43.1265 of 100 13.1327 s/rollout
# 2018-05-26 01:16:30,462 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 564224, min/mean/max reward 13.7074/16.4889/19.2705 of 2
# 2018-05-26 01:16:30,463 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/20.7532/43.1265 of 100 13.1423 s/rollout
# 2018-05-26 01:20:50,989 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 574464, min/mean/max reward 50.4151/73.6673/96.9194 of 2
# 2018-05-26 01:20:50,990 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/22.3591/73.6673 of 100 13.1402 s/rollout
# 2018-05-26 01:25:11,628 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 584704, min/mean/max reward 13.0228/14.9996/16.9765 of 2
# 2018-05-26 01:25:11,629 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/22.1077/73.6673 of 100 13.1424 s/rollout
# 2018-05-26 01:29:32,708 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 594944, min/mean/max reward 27.4205/31.5618/35.7031 of 2
# 2018-05-26 01:29:32,709 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/22.5786/73.6673 of 100 13.1479 s/rollout
# 2018-05-26 01:33:54,195 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 605184, min/mean/max reward 19.4836/23.6183/27.7530 of 2
# 2018-05-26 01:33:54,196 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/23.8471/73.6673 of 100 13.1507 s/rollout
# 2018-05-26 01:38:16,709 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 615424, min/mean/max reward 19.4836/23.6183/27.7530 of 2
# 2018-05-26 01:38:16,710 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9500/25.1395/73.6673 of 100 13.1581 s/rollout
# 2018-05-26 01:42:39,306 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 625664, min/mean/max reward 3.6940/17.0568/30.4196 of 2
# 2018-05-26 01:42:39,307 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 11.9950/25.0413/73.6673 of 100 13.1674 s/rollout
# 2018-05-26 01:47:01,242 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 635904, min/mean/max reward 21.2273/24.3289/27.4304 of 2
# 2018-05-26 01:47:01,243 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 11.7217/23.4021/73.6673 of 100 13.1460 s/rollout
# 2018-05-26 01:51:22,492 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 646144, min/mean/max reward 28.1528/29.2265/30.3002 of 2
# 2018-05-26 01:51:22,493 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 11.7217/22.6185/73.6673 of 100 13.1131 s/rollout
# 2018-05-26 01:55:43,090 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 656384, min/mean/max reward 3.7212/5.2325/6.7439 of 2
# 2018-05-26 01:55:43,091 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/22.7432/73.6673 of 100 13.0732 s/rollout
# 2018-05-26 02:00:04,460 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 666624, min/mean/max reward 5.4448/16.5624/27.6800 of 2
# 2018-05-26 02:00:04,460 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/22.8328/73.6673 of 100 13.0700 s/rollout
# 2018-05-26 02:04:26,319 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 676864, min/mean/max reward 6.6728/28.5440/50.4151 of 2
# 2018-05-26 02:04:26,320 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/20.4376/56.3439 of 100 13.0766 s/rollout
# 2018-05-26 02:08:49,459 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 687104, min/mean/max reward 17.7359/35.5116/53.2874 of 2
# 2018-05-26 02:08:49,460 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/20.0142/35.5116 of 100 13.0892 s/rollout
# 2018-05-26 02:13:11,586 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 697344, min/mean/max reward 6.9392/7.1760/7.4127 of 2
# 2018-05-26 02:13:11,587 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/20.3957/35.5116 of 100 13.0944 s/rollout
# 2018-05-26 02:17:33,801 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 707584, min/mean/max reward 17.1130/21.8730/26.6330 of 2
# 2018-05-26 02:17:33,802 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/19.5164/35.5116 of 100 13.0980 s/rollout
# 2018-05-26 02:21:55,232 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 717824, min/mean/max reward 13.0228/16.2532/19.4836 of 2
# 2018-05-26 02:21:55,233 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 5.2325/18.7896/35.5116 of 100 13.0926 s/rollout
# 2018-05-26 02:26:16,548 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 728064, min/mean/max reward 6.6140/19.6221/32.6303 of 2
# 2018-05-26 02:26:16,549 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/17.5218/35.5116 of 100 13.0862 s/rollout
# 2018-05-26 02:30:37,022 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 738304, min/mean/max reward 14.4552/15.1321/15.8089 of 2
# 2018-05-26 02:30:37,023 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/17.4042/35.5116 of 100 13.0789 s/rollout
# 2018-05-26 02:34:58,970 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 748544, min/mean/max reward 10.3519/16.2830/22.2141 of 2
# 2018-05-26 02:34:58,971 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/17.3706/35.5116 of 100 13.0824 s/rollout
# 2018-05-26 02:39:20,658 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 758784, min/mean/max reward 29.1830/29.8013/30.4196 of 2
# 2018-05-26 02:39:20,659 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/17.9865/35.5116 of 100 13.0878 s/rollout
# 2018-05-26 02:43:41,313 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 769024, min/mean/max reward 31.0718/34.6174/38.1629 of 2
# 2018-05-26 02:43:41,314 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/19.0460/35.5116 of 100 13.0843 s/rollout
# 2018-05-26 02:48:02,780 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 779264, min/mean/max reward 6.6140/7.8900/9.1659 of 2
# 2018-05-26 02:48:02,781 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/19.3554/35.5116 of 100 13.0823 s/rollout
# 2018-05-26 02:52:24,011 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 789504, min/mean/max reward 2.8953/15.0218/27.1483 of 2
# 2018-05-26 02:52:24,013 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/19.4050/35.5116 of 100 13.0728 s/rollout
# 2018-05-26 02:56:44,591 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 799744, min/mean/max reward 3.3792/4.9986/6.6180 of 2
# 2018-05-26 02:56:44,592 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.5390/18.6254/34.6174 of 100 13.0650 s/rollout
# 2018-05-26 03:01:05,877 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 809984, min/mean/max reward 28.9358/36.0444/43.1529 of 2
# 2018-05-26 03:01:05,878 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/17.8540/36.0444 of 100 13.0604 s/rollout
# 2018-05-26 03:05:27,030 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 820224, min/mean/max reward 11.7261/15.2894/18.8527 of 2
# 2018-05-26 03:05:27,031 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/19.1721/36.0444 of 100 13.0590 s/rollout
# 2018-05-26 03:09:48,082 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 830464, min/mean/max reward 27.4205/41.6425/55.8645 of 2
# 2018-05-26 03:09:48,083 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/21.2336/41.6425 of 100 13.0577 s/rollout
# 2018-05-26 03:14:09,732 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 840704, min/mean/max reward 3.0566/8.0958/13.1350 of 2
# 2018-05-26 03:14:09,733 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/21.0748/41.6425 of 100 13.0636 s/rollout
# 2018-05-26 03:18:30,669 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 850944, min/mean/max reward 17.2934/18.9489/20.6044 of 2
# 2018-05-26 03:18:30,670 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/20.4075/41.6425 of 100 13.0585 s/rollout
# 2018-05-26 03:22:51,541 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 861184, min/mean/max reward 8.0495/12.2523/16.4552 of 2
# 2018-05-26 03:22:51,542 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/19.9266/58.4675 of 100 13.0544 s/rollout
# 2018-05-26 03:27:12,470 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 871424, min/mean/max reward 14.4552/15.1321/15.8089 of 2
# 2018-05-26 03:27:12,471 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/18.4858/58.4675 of 100 13.0558 s/rollout
# 2018-05-26 03:31:34,239 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 881664, min/mean/max reward 19.2363/37.5518/55.8672 of 2
# 2018-05-26 03:31:34,240 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/18.0560/58.4675 of 100 13.0573 s/rollout
# 2018-05-26 03:35:55,545 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 891904, min/mean/max reward 10.5132/13.1393/15.7654 of 2
# 2018-05-26 03:35:55,546 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/19.1951/58.4675 of 100 13.0577 s/rollout
# 2018-05-26 03:40:16,187 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 902144, min/mean/max reward 6.6848/13.0265/19.3682 of 2
# 2018-05-26 03:40:16,188 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.4079/20.0716/58.4675 of 100 13.0580 s/rollout
# 2018-05-26 03:44:37,056 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 912384, min/mean/max reward 4.1155/9.9419/15.7683 of 2
# 2018-05-26 03:44:37,058 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 8.0958/20.1745/58.4675 of 100 13.0559 s/rollout
# 2018-05-26 03:48:58,886 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 922624, min/mean/max reward 19.4836/36.3888/53.2941 of 2
# 2018-05-26 03:48:58,887 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 8.0958/18.8401/58.4675 of 100 13.0593 s/rollout
# 2018-05-26 03:53:19,740 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 932864, min/mean/max reward 17.1130/19.3912/21.6693 of 2
# 2018-05-26 03:53:19,741 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 8.0958/19.0241/58.4675 of 100 13.0583 s/rollout
# 2018-05-26 03:57:40,582 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 943104, min/mean/max reward 10.2228/52.6734/95.1239 of 2
# 2018-05-26 03:57:40,583 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 8.0958/20.2048/58.4675 of 100 13.0542 s/rollout
# 2018-05-26 04:02:01,660 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 953344, min/mean/max reward 11.8054/20.2697/28.7340 of 2
# 2018-05-26 04:02:01,661 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 9.9419/22.9791/58.4675 of 100 13.0550 s/rollout
# 2018-05-26 04:06:22,198 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 963584, min/mean/max reward 6.6140/11.1911/15.7683 of 2
# 2018-05-26 04:06:22,199 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 9.9419/23.1256/52.6734 of 100 13.0533 s/rollout
# 2018-05-26 04:10:43,920 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 973824, min/mean/max reward 4.1239/16.4477/28.7715 of 2
# 2018-05-26 04:10:43,920 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 9.9419/23.6994/52.6734 of 100 13.0572 s/rollout
# 2018-05-26 04:15:05,196 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 984064, min/mean/max reward 6.8867/17.6948/28.5028 of 2
# 2018-05-26 04:15:05,198 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.1733/23.2750/52.6734 of 100 13.0548 s/rollout
# 2018-05-26 04:19:26,359 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 994304, min/mean/max reward 16.9221/21.4079/25.8936 of 2
# 2018-05-26 04:19:26,360 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.1733/22.1607/52.6734 of 100 13.0541 s/rollout
# 2018-05-26 04:23:47,211 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1004544, min/mean/max reward 6.6014/13.0425/19.4836 of 2
# 2018-05-26 04:23:47,212 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.1733/21.6920/52.6734 of 100 13.0551 s/rollout
# 2018-05-26 04:28:08,953 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1014784, min/mean/max reward 3.7257/15.5731/27.4205 of 2
# 2018-05-26 04:28:08,954 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.1733/22.1546/52.6734 of 100 13.0595 s/rollout
# 2018-05-26 04:32:29,822 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1025024, min/mean/max reward 6.8024/17.7333/28.6642 of 2
# 2018-05-26 04:32:29,823 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/21.6889/52.6734 of 100 13.0547 s/rollout
# 2018-05-26 04:36:51,318 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1035264, min/mean/max reward 5.9472/12.7111/19.4751 of 2
# 2018-05-26 04:36:51,319 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/20.4097/52.6734 of 100 13.0579 s/rollout
# 2018-05-26 04:41:11,985 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1045504, min/mean/max reward 17.1130/21.9906/26.8681 of 2
# 2018-05-26 04:41:11,985 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/19.6650/52.6734 of 100 13.0570 s/rollout
# 2018-05-26 04:45:32,732 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1055744, min/mean/max reward 6.6140/14.7320/22.8501 of 2
# 2018-05-26 04:45:32,733 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/16.7172/27.9599 of 100 13.0554 s/rollout
# 2018-05-26 04:49:53,634 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1065984, min/mean/max reward 4.2194/6.1986/8.1779 of 2
# 2018-05-26 04:49:53,635 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/16.2659/27.9599 of 100 13.0572 s/rollout
# 2018-05-26 04:54:14,367 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1076224, min/mean/max reward 6.6140/17.2803/27.9466 of 2
# 2018-05-26 04:54:14,368 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/15.6377/26.8953 of 100 13.0522 s/rollout
# 2018-05-26 04:58:35,317 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1086464, min/mean/max reward 16.9170/17.8917/18.8664 of 2
# 2018-05-26 04:58:35,318 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/15.8403/26.8953 of 100 13.0506 s/rollout
# 2018-05-26 05:02:56,394 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1096704, min/mean/max reward 6.4577/12.0968/17.7359 of 2
# 2018-05-26 05:02:56,395 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/15.3857/24.3269 of 100 13.0502 s/rollout
# 2018-05-26 05:07:17,550 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1106944, min/mean/max reward 4.2419/8.7992/13.3565 of 2
# 2018-05-26 05:07:17,551 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/14.5536/24.3269 of 100 13.0517 s/rollout
# 2018-05-26 05:11:38,258 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1117184, min/mean/max reward 5.4598/9.0994/12.7390 of 2
# 2018-05-26 05:11:38,259 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.2419/13.8903/23.1758 of 100 13.0465 s/rollout
# 2018-05-26 05:15:59,068 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1127424, min/mean/max reward 4.2419/5.7253/7.2087 of 2
# 2018-05-26 05:15:59,069 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/13.6646/23.1758 of 100 13.0462 s/rollout
# 2018-05-26 05:20:20,186 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1137664, min/mean/max reward 12.4001/12.7114/13.0228 of 2
# 2018-05-26 05:20:20,187 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/13.0193/23.1758 of 100 13.0443 s/rollout
# 2018-05-26 05:24:41,332 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1147904, min/mean/max reward 4.7538/14.6205/24.4872 of 2
# 2018-05-26 05:24:41,333 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/12.7127/25.8178 of 100 13.0467 s/rollout
# 2018-05-26 05:29:02,310 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1158144, min/mean/max reward 4.2474/9.9621/15.6769 of 2
# 2018-05-26 05:29:02,311 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/12.4042/25.8178 of 100 13.0479 s/rollout
# 2018-05-26 05:33:23,102 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1168384, min/mean/max reward 6.3346/7.3326/8.3305 of 2
# 2018-05-26 05:33:23,103 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/11.7728/25.8178 of 100 13.0473 s/rollout
# 2018-05-26 05:37:44,191 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1178624, min/mean/max reward 6.6140/8.4184/10.2228 of 2
# 2018-05-26 05:37:44,193 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/11.2963/25.8178 of 100 13.0491 s/rollout
# 2018-05-26 05:42:05,803 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1188864, min/mean/max reward 20.7766/58.1597/95.5428 of 2
# 2018-05-26 05:42:05,804 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/11.3615/58.1597 of 100 13.0524 s/rollout
# 2018-05-26 05:46:27,336 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1199104, min/mean/max reward 13.1350/13.4693/13.8035 of 2
# 2018-05-26 05:46:27,337 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 2.9452/14.2497/58.1597 of 100 13.0547 s/rollout
# 2018-05-26 05:50:48,983 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1209344, min/mean/max reward 11.2955/12.2153/13.1350 of 2
# 2018-05-26 05:50:48,983 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/14.8634/58.1597 of 100 13.0572 s/rollout
# 2018-05-26 05:55:09,982 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1219584, min/mean/max reward 13.0228/16.2661/19.5095 of 2
# 2018-05-26 05:55:09,983 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/15.5196/58.1597 of 100 13.0586 s/rollout
# 2018-05-26 05:59:31,744 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1229824, min/mean/max reward 17.0034/18.1796/19.3558 of 2
# 2018-05-26 05:59:31,745 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/16.5643/58.1597 of 100 13.0634 s/rollout
# 2018-05-26 06:03:54,195 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1240064, min/mean/max reward 18.6100/23.0152/27.4205 of 2
# 2018-05-26 06:03:54,197 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/17.5239/58.1597 of 100 13.0700 s/rollout
# 2018-05-26 06:08:16,666 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1250304, min/mean/max reward 19.5522/58.3831/97.2139 of 2
# 2018-05-26 06:08:16,667 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/19.7781/62.3172 of 100 13.0767 s/rollout
# 2018-05-26 06:12:38,675 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1260544, min/mean/max reward 22.8501/35.0886/47.3271 of 2
# 2018-05-26 06:12:38,676 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/23.2825/62.3172 of 100 13.0818 s/rollout
# 2018-05-26 06:17:00,189 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1270784, min/mean/max reward 8.1731/11.3142/14.4552 of 2
# 2018-05-26 06:17:00,190 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/24.4123/62.3172 of 100 13.0854 s/rollout
# 2018-05-26 06:21:21,156 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1281024, min/mean/max reward 14.4552/21.6573/28.8594 of 2
# 2018-05-26 06:21:21,158 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 4.2058/25.1050/62.3172 of 100 13.0848 s/rollout
# 2018-05-26 06:25:42,440 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1291264, min/mean/max reward 26.1413/26.6448/27.1483 of 2
# 2018-05-26 06:25:42,441 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 9.4233/25.9215/62.3172 of 100 13.0832 s/rollout
# 2018-05-26 06:30:04,136 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1301504, min/mean/max reward 27.1483/27.2844/27.4205 of 2
# 2018-05-26 06:30:04,138 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 9.8591/23.7405/62.3172 of 100 13.0840 s/rollout
# 2018-05-26 06:34:25,407 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1311744, min/mean/max reward 6.5880/18.3138/30.0396 of 2
# 2018-05-26 06:34:25,408 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 9.8591/24.0228/62.3172 of 100 13.0821 s/rollout
# 2018-05-26 06:38:46,940 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1321984, min/mean/max reward 26.5921/35.6218/44.6516 of 2
# 2018-05-26 06:38:46,941 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.0541/25.1832/62.3172 of 100 13.0848 s/rollout
# 2018-05-26 06:43:08,851 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1332224, min/mean/max reward 10.9434/11.9831/13.0228 of 2
# 2018-05-26 06:43:08,852 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.0541/25.0811/62.3172 of 100 13.0855 s/rollout
# 2018-05-26 06:47:30,618 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1342464, min/mean/max reward 4.2474/11.9126/19.5778 of 2
# 2018-05-26 06:47:30,619 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 7.0248/24.0944/62.3172 of 100 13.0821 s/rollout
# 2018-05-26 06:51:52,597 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1352704, min/mean/max reward 4.8932/6.4100/7.9269 of 2
# 2018-05-26 06:51:52,598 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/20.9885/58.3831 of 100 13.0797 s/rollout
# 2018-05-26 06:56:14,178 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1362944, min/mean/max reward 4.3021/11.8361/19.3701 of 2
# 2018-05-26 06:56:14,179 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/18.2649/37.6746 of 100 13.0775 s/rollout
# 2018-05-26 07:00:35,666 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1373184, min/mean/max reward 16.7133/24.6630/32.6127 of 2
# 2018-05-26 07:00:35,667 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/17.9210/35.6218 of 100 13.0774 s/rollout
# 2018-05-26 07:04:57,061 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1383424, min/mean/max reward 14.3389/22.7053/31.0718 of 2
# 2018-05-26 07:04:57,063 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/18.7812/35.6218 of 100 13.0795 s/rollout
# 2018-05-26 07:09:22,489 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1393664, min/mean/max reward 9.7862/10.5975/11.4087 of 2
# 2018-05-26 07:09:22,490 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/17.7954/35.6218 of 100 13.1002 s/rollout
# 2018-05-26 07:13:57,308 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1403904, min/mean/max reward 18.6124/20.7312/22.8501 of 2
# 2018-05-26 07:13:57,309 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/17.1997/35.6218 of 100 13.1659 s/rollout
# 2018-05-26 07:18:30,793 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1414144, min/mean/max reward 3.6170/13.3869/23.1569 of 2
# 2018-05-26 07:18:30,794 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/16.7377/35.6218 of 100 13.2269 s/rollout
# 2018-05-26 07:23:01,504 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1424384, min/mean/max reward 17.1130/32.2201/47.3271 of 2
# 2018-05-26 07:23:01,505 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/16.9346/33.3415 of 100 13.2728 s/rollout
# 2018-05-26 07:27:34,390 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: total steps 1434624, min/mean/max reward 1.0619/16.7491/32.4363 of 2
# 2018-05-26 07:27:34,391 - RNN_v3b_256im_512z_1512_v6c_VAE5_all - INFO: running min/mean/max reward 6.4100/17.2292/33.3415 of 100 13.3277 s/rollout
# saving ./outputs/models/PPO_512z_all_c.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-90590f8c6bb3> in <module>()
#       1 try:
# ----> 2     run_iterations(agent, log_dir=log_dir)
#       3 except:
#       4     if config.num_workers==1:
#       5         agent.task.tasks[0].env.close()
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/helpers/deep_rl.py in run_iterations(agent, log_dir)
#     149     # with tqdm(mininterval=1, unit='it', total=config.max_steps, leave=True) as prog:
#     150     while True:
# --> 151         agent.iteration()
#     152         steps.append(agent.total_steps)
#     153         rewards.append(np.mean(agent.last_episode_rewards))
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/helpers/deep_rl.py in iteration(self)
#      55         states = self.states
#      56         for _ in range(config.rollout_length):
# ---> 57             actions, log_probs, _, values = self.network.predict(states)
#      58             next_states, rewards, terminals, _ = self.task.step(actions.cpu().detach().numpy())
#      59             self.episode_rewards += rewards
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/helpers/deep_rl.py in predict(self, obs, action)
#     229             if self.hidden_state and (obs.size(0) != self.hidden_state[0].size(0) or obs.size(1) != self.hidden_state[0].size(1)):
#     230                 self.hidden_state = None
# --> 231             z_next, z, hidden_state = self.world_model.forward(obs, hidden_state=self.hidden_state)
#     232
#     233             hidden_state = [h.data for h in hidden_state]  # Otherwise it doesn't garbge collect
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/models/world_model.py in forward(self, x, action, hidden_state)
#      14         _, mu_vae, logvar_vae = self.vae.forward(x)
#      15         z = self.vae.sample(mu_vae, logvar_vae)
# ---> 16         pi, mu, sigma, hidden_state = self.mdnrnn.forward(z[:, None], action, hidden_state=hidden_state)
#      17         z_next_pred = self.mdnrnn.sample(pi, mu, sigma)
#      18         return z_next_pred.squeeze(1), z, hidden_state
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/models/rnn.py in forward(self, inpt, action_discrete, hidden_state)
#      55         cuda = next(iter(self.parameters())).is_cuda
#      56         if cuda:
# ---> 57             action = action.cuda()
#      58
#      59         if hidden_state is None:
#
# KeyboardInterrupt:

# %% [markdown]
# To monitor with tensorboard
# ```sh
# cd ~/Documents/projects/retro_sonic_comp/world-models-pytorch/log
# tensorboard  --logdir .
# #then open http://localhost:6006/#scalars
# ```
