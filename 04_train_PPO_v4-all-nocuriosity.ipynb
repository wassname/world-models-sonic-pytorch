# %% [markdown]
# This experiment, higher learning rate. Larger rollouts.

# %%
import deep_rl

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import torch
from torch.nn import functional as F
from torch.autograd import Variable
from torch import nn, optim
import torch.utils.data

# load as dask array
import time

import logging
import sys
import os
import glob
import numpy as np
import datetime
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook as tqdm

# %%
from deep_rl.utils.logger import get_logger, get_default_log_dir

from deep_rl.network.network_heads import CategoricalActorCriticNet, QuantileNet, OptionCriticNet, DeterministicActorCriticNet, GaussianActorCriticNet
from deep_rl.network.network_bodies import FCBody
from deep_rl.utils.normalizer import RunningStatsNormalizer, RescaleNormalizer
from deep_rl.component.task import ParallelizedTask

# %%
from world_models_sonic.models.vae import VAE5, loss_function_vae
from world_models_sonic.helpers.summarize import TorchSummarizeDf
from world_models_sonic.models.rnn import MDNRNN
from world_models_sonic.models.inverse_model import InverseModel2
from world_models_sonic.models.world_model import WorldModel
from world_models_sonic.custom_envs.env import make_env
from world_models_sonic.custom_envs.wrappers import RandomGameReset
from world_models_sonic import config
from world_models_sonic.helpers.deep_rl import PPOAgent, run_iterations, SonicWorldModelDeepRL, CategoricalWorldActorCriticNet, Config
# Out:
# Importing 0 potential games...
# Imported 0 games

# %% [markdown]
# # Init

# %%
env_name = 'sonic256'
z_dim = 512  # latent dimensions
channels = 3

# RNN
action_dim = 10
image_size = 128

verbose = True  # Set this true to render (and make it go slower)

NAME = 'RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack'
ppo_save_file = './outputs/{NAME}/PPO_512z_all_g.pkl'.format(NAME=NAME)
cuda = torch.cuda.is_available()

# %%
# Logging
if not os.path.isdir('./outputs/{NAME}'.format(NAME=NAME)):
    os.makedirs('./outputs/{NAME}'.format(NAME=NAME))

# Log to file and stream
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logger = logging.getLogger(NAME)

log_dir = log_dir='./outputs/{NAME}'.format(NAME=NAME)
print(log_dir)

deep_rl_logger = get_logger(
    NAME[-10:],
    file_name='deep_rl_ppo.log',
    level=logging.INFO,
    log_dir='./outputs/{NAME}'.format(NAME=NAME), )
# Out:
# ./outputs/RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack

# %% [markdown]
# # World model

# %%
# Load VAE
# TODO swap z and k dim, since it's inconsistent with other models
vae = VAE5(image_size=image_size, z_dim=128, conv_dim=64, code_dim=8, k_dim=z_dim, channels=channels)
    
# Load MDRNN
action_dim, hidden_size, n_mixture, temp = action_dim, z_dim*2, 5, 1.0

mdnrnn = MDNRNN(z_dim, action_dim, hidden_size, n_mixture, temp)
    
finv = InverseModel2(z_dim, action_dim, hidden_size=64)
    
world_model = WorldModel(vae, mdnrnn, finv, logger=deep_rl_logger, lambda_vae_kld=1 / 12., lambda_finv=1/200, lambda_vae=1/8, lambda_loss=1000)
world_model = world_model.train()
if cuda:
    world_model = world_model.cuda()

# %%
# Optimiser for world models
import torch.optim.lr_scheduler
torch.cuda.empty_cache()
optimizer = optim.Adam(world_model.parameters(), lr=4e-5)

world_model.optimizer = optimizer

# %% [markdown]
# # Train

# %%
# batch: We have two differen't batch sizes, determined by your gpu:
# VAE: rollout_length * world_model_batch_size which is how much VAE data you can get in your gpu, for my 8GB gpu it was ~50
# PPO: (config.rollout_length*config.num_workers)/config.num_mini_batches: how much PPO data you can git for me it was ~500


z_state_dim=world_model.mdnrnn.z_dim + world_model.mdnrnn.hidden_size


def task_fn(log_dir):
    return SonicWorldModelDeepRL(
        env_fn=lambda: RandomGameReset(make_env(
            'sonic', max_episode_steps=4000, to_gray=False, image_size=image_size)),
        log_dir=log_dir,
        verbose=verbose
    )

config = Config()

verbose = False  # Set this true to render (and make it go slower)
config.num_workers = 1 if verbose else 10
config.task_fn = lambda: ParallelizedTask(
    task_fn, config.num_workers, single_process=config.num_workers == 1)
config.optimizer_fn = lambda params: torch.optim.Adam(params, 1e-4, eps=1e-6)
config.network_fn = lambda state_dim, action_dim: CategoricalWorldActorCriticNet(
    state_dim, action_dim, FCBody(z_state_dim, hidden_units=(64, 64), gate=F.relu), gpu=0 if cuda else -1, world_model_fn=lambda: world_model,
    render=(config.num_workers==1 and verbose),
    z_shape=(32, 16)
)
# see params here https://github.com/openai/retro-baselines/blob/master/agents/ppo2_agent.py
config.discount = 0.99
config.logger = deep_rl_logger
config.use_gae = True
config.gae_tau = 0.95
config.entropy_weight = 0.02
config.value_weight = 0.5
config.gradient_clip = 0.5  # Watch grad_norm in tensorboard and set this to upper quartile to avoid clipping too much
config.rollout_length = 36
config.optimization_epochs = 3
config.num_mini_batches = 8
config.ppo_ratio_clip = 0.1
config.iteration_log_interval = 1

config.train_world_model = False
if not config.train_world_model:
    config.rollout_length*=12  # More can fit in batch
config.world_model_batch_size = 2

# I tuned these so the intrinsic reward was 1) within an order of magnitude of the extrinsic. 2) smaller, 3) negative when stuck
# TODO use reward normalisers etc to reduce the need for these hyperparameters
config.curiosity = False
config.curiosity_only = False
config.curiosity_weight = 0.01
config.curiosity_boredom = 2 # how many standard deviations above the mean does it's new experience need to be, so it's not bored
# config.reward_normalizer = RunningStatsNormalizer()
# config.intrinsic_reward_normalizer = RunningStatsNormalizer()
agent = PPOAgent(config)

print(('total rollout of ', config.rollout_length*config.num_workers))
print(('made of sequences of length', (config.rollout_length)))
print(('ppo mini batch', (config.rollout_length*config.num_workers)//config.num_mini_batches))


if os.path.isfile(ppo_save_file):
    print(('loading ppo_save_file', ppo_save_file, 'modified', time.ctime(os.path.getmtime(ppo_save_file))))
    agent.load(ppo_save_file)
    
#     # also load normalizers
    state_dict = torch.load(ppo_save_file.replace('.pkl', '-intrinsic_reward_normalizer.pkl'))
    config.intrinsic_reward_normalizer.load_state_dict(state_dict)

    state_dict = torch.load(ppo_save_file.replace('.pkl', '-reward_normalizer.pkl'))
    config.reward_normalizer.load_state_dict(state_dict)
else:
    print("couldn't find save")
# Out:
# game: SonicAndKnuckles3-Genesis state: MarbleGardenZone.Act1
# game: SonicTheHedgehog2-Genesis state: EmeraldHillZone.Act2
# game: SonicTheHedgehog-Genesis state: ScrapBrainZone.Act2
# game: SonicTheHedgehog2-Genesis state: MetropolisZone.Act1
# game: SonicTheHedgehog-Genesis state: SpringYardZone.Act2
# game: SonicAndKnuckles3-Genesis state: SandopolisZone.Act1
# game: SonicAndKnuckles3-Genesis state: DeathEggZone.Act1
# game: SonicTheHedgehog2-Genesis state: EmeraldHillZone.Act1
# game: SonicAndKnuckles3-Genesis state: AngelIslandZone.Act1
# game: SonicAndKnuckles3-Genesis state: DeathEggZone.Act1
# ('total rollout of ', 4320)
# ('made of sequences of length', 432)
# ('ppo mini batch', 540)
# ('loading ppo_save_file', './outputs/RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack/PPO_512z_all_g.pkl', 'modified', 'Fri Jun 22 16:57:50 2018')
# Process ProcessWrapper-8:
# Process ProcessWrapper-4:
# Process ProcessWrapper-5:
# Traceback (most recent call last):
# Process ProcessWrapper-7:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ProcessWrapper-9:
# Process ProcessWrapper-2:
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
# Process ProcessWrapper-6:
# Process ProcessWrapper-3:
# Process ProcessWrapper-1:
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
# Traceback (most recent call last):
# Process ProcessWrapper-10:
# Traceback (most recent call last):
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Traceback (most recent call last):
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/media/oldhome/wassname/Documents/projects/retro_sonic_comp/DeepRL/deep_rl/component/task.py", line 177, in run
#     op, data = self.pipe.recv()
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/wassname/.pyenv/versions/3.5.3/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
# # DEBUG

# # reset from checkpoint
# agent.load('./outputs/RNN_v3b_128im_512z_1512_v6j_VAE5_all/PPO_512z_all_g-20180606_02-06-59.pkl')

# # # Reset just rnn
# world_model.mdnrnn = MDNRNN(z_dim, action_dim, hidden_size, n_mixture, temp)
# world_model.mdnrnn.cuda()

# # if we want to reset the actor
# from deep_rl.network.network_heads import ActorCriticNet
# agent.network.network = ActorCriticNet(agent.network.z_state_dim, action_dim, FCBody(z_state_dim, hidden_units=(64, 64), gate=F.relu), None, None)
# agent.network.network.cuda()


# world_model.finv = finv = InverseModel(z_dim, action_dim, hidden_size=z_dim*2)
# world_model.finv.cuda()

# %%
# agent.load('/home/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/outputs/RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack/PPO_512z_all_g-20180622_06-38-24.pkl')

# %%
print(""""
# To monitor with tensorboard at http://localhost:6006/
cd ./outputs/{NAME}/
tensorboard  --logdir .
""".format(NAME=NAME))
# Out:
# "
# # To monitor with tensorboard at http://localhost:6006/
# cd ./outputs/RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack/
# tensorboard  --logdir .

# %%
try:
    run_iterations(agent, log_dir=log_dir)
except KeyboardInterrupt:
    # Close the environment
    if config.num_workers == 1:
        agent.task.tasks[0].env.close()
    else:
        [t.close() for t in agent.task.tasks]

    print("saving", ppo_save_file)
    agent.save(ppo_save_file)
#     torch.save(config.intrinsic_reward_normalizer.state_dict(), ppo_save_file.replace('.pkl', '-intrinsic_reward_normalizer.pkl'))
#     torch.save(config.reward_normalizer.state_dict(), ppo_save_file.replace('.pkl', '-reward_normalizer.pkl'))

    # Backup since it sometimes get's corrupted
    ts = datetime.datetime.utcnow().strftime('%Y%m%d_%H-%M-%S')
    print("saving backup",
          ppo_save_file.replace('.pkl', '-%s.pkl' % ts),)
    agent.save(ppo_save_file.replace('.pkl', '-%s.pkl' % ts))
    raise
# Out:
# 2018-06-22 16:58:54,533 - framestack - INFO: action counts: {0: 334, 1: 89, 2: 1027, 3: 46, 4: 1041, 5: 200, 6: 282, 7: 73, 8: 893, 9: 335}
# 2018-06-22 16:58:54,558 - framestack - INFO: steps: 4320, steps/s: 88.58
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=10]
#
# 2018-06-22 16:59:44,564 - framestack - INFO: action counts: {0: 317, 1: 91, 2: 1105, 3: 45, 4: 1009, 5: 230, 6: 231, 7: 79, 8: 902, 9: 311}
# 2018-06-22 16:59:44,590 - framestack - INFO: steps: 8640, steps/s: 87.46
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=20]
#
# 2018-06-22 17:00:34,102 - framestack - INFO: action counts: {0: 316, 1: 83, 2: 1063, 3: 35, 4: 1028, 5: 218, 6: 262, 7: 65, 8: 891, 9: 359}
# 2018-06-22 17:00:34,124 - framestack - INFO: steps: 12960, steps/s: 87.38
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=30]
#
# 2018-06-22 17:01:23,333 - framestack - INFO: action counts: {0: 301, 1: 78, 2: 1085, 3: 44, 4: 1032, 5: 251, 6: 277, 7: 62, 8: 855, 9: 335}
# 2018-06-22 17:01:23,355 - framestack - INFO: steps: 17280, steps/s: 87.47
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=40]
#
# 2018-06-22 17:02:11,039 - framestack - INFO: action counts: {0: 305, 1: 83, 2: 1080, 3: 33, 4: 1012, 5: 247, 6: 281, 7: 80, 8: 864, 9: 335}
# 2018-06-22 17:02:11,063 - framestack - INFO: steps: 21600, steps/s: 88.09
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=50]
#
# 2018-06-22 17:02:59,893 - framestack - INFO: action counts: {0: 293, 1: 88, 2: 1051, 3: 53, 4: 972, 5: 271, 6: 285, 7: 93, 8: 901, 9: 313}
# 2018-06-22 17:02:59,924 - framestack - INFO: steps: 25920, steps/s: 88.14
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=60]
#
# 2018-06-22 17:03:50,231 - framestack - INFO: action counts: {0: 361, 1: 101, 2: 975, 3: 56, 4: 1018, 5: 239, 6: 317, 7: 106, 8: 826, 9: 321}
# 2018-06-22 17:03:50,255 - framestack - INFO: steps: 30240, steps/s: 87.81
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=70]
#
# 2018-06-22 17:04:40,585 - framestack - INFO: action counts: {0: 315, 1: 90, 2: 1048, 3: 60, 4: 995, 5: 221, 6: 304, 7: 90, 8: 859, 9: 338}
# 2018-06-22 17:04:40,611 - framestack - INFO: steps: 34560, steps/s: 87.56
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=80]
#
# 2018-06-22 17:05:30,522 - framestack - INFO: action counts: {0: 329, 1: 108, 2: 1054, 3: 69, 4: 990, 5: 250, 6: 305, 7: 97, 8: 792, 9: 326}
# 2018-06-22 17:05:30,548 - framestack - INFO: steps: 38880, steps/s: 87.44
#   epoch reward:       0.0000/1.2000/7.9751 [n=10] (min/mean/max)
#   running reward:     0.0000/1.2000/7.9751 [n=90]
#
# 2018-06-22 17:06:19,951 - framestack - INFO: action counts: {0: 303, 1: 101, 2: 1015, 3: 72, 4: 985, 5: 247, 6: 298, 7: 89, 8: 809, 9: 401}
# 2018-06-22 17:06:19,972 - framestack - INFO: steps: 43200, steps/s: 87.44
#   epoch reward:       1.3966/9.3446/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/2.0144/26.6303 [n=100]
#
# 2018-06-22 17:07:09,138 - framestack - INFO: action counts: {0: 294, 1: 101, 2: 1015, 3: 79, 4: 955, 5: 266, 6: 325, 7: 92, 8: 844, 9: 349}
# 2018-06-22 17:07:09,163 - framestack - INFO: steps: 47520, steps/s: 87.47
#   epoch reward:       3.9264/12.6442/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/2.9808/26.6303 [n=110]
#
# 2018-06-22 17:07:59,641 - framestack - INFO: action counts: {0: 291, 1: 108, 2: 1013, 3: 52, 4: 964, 5: 261, 6: 307, 7: 85, 8: 903, 9: 336}
# 2018-06-22 17:07:59,666 - framestack - INFO: steps: 51840, steps/s: 87.31
#   epoch reward:       3.9264/11.0624/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/3.6542/26.6303 [n=120]
#
# 2018-06-22 17:08:49,823 - framestack - INFO: action counts: {0: 305, 1: 79, 2: 1072, 3: 46, 4: 1013, 5: 246, 6: 274, 7: 96, 8: 850, 9: 339}
# 2018-06-22 17:08:49,849 - framestack - INFO: steps: 56160, steps/s: 87.22
#   epoch reward:       3.9264/11.7436/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/4.2765/26.6303 [n=130]
#
# 2018-06-22 17:09:40,620 - framestack - INFO: action counts: {0: 332, 1: 67, 2: 1076, 3: 57, 4: 922, 5: 248, 6: 260, 7: 66, 8: 914, 9: 378}
# 2018-06-22 17:09:40,647 - framestack - INFO: steps: 60480, steps/s: 87.06
#   epoch reward:       3.9264/11.7436/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/4.8099/26.6303 [n=140]
#
# 2018-06-22 17:10:30,393 - framestack - INFO: action counts: {0: 309, 1: 78, 2: 1051, 3: 56, 4: 978, 5: 240, 6: 250, 7: 87, 8: 907, 9: 364}
# 2018-06-22 17:10:30,419 - framestack - INFO: steps: 64800, steps/s: 87.04
#   epoch reward:       3.9264/10.9160/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/5.2169/26.6303 [n=150]
#
# 2018-06-22 17:11:18,116 - framestack - INFO: action counts: {0: 319, 1: 93, 2: 1060, 3: 51, 4: 975, 5: 256, 6: 262, 7: 79, 8: 861, 9: 364}
# 2018-06-22 17:11:18,138 - framestack - INFO: steps: 69120, steps/s: 87.26
#   epoch reward:       3.9264/10.9160/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/5.5731/26.6303 [n=160]
#
# 2018-06-22 17:12:07,708 - framestack - INFO: action counts: {0: 327, 1: 105, 2: 1066, 3: 47, 4: 949, 5: 228, 6: 278, 7: 105, 8: 839, 9: 376}
# 2018-06-22 17:12:07,738 - framestack - INFO: steps: 73440, steps/s: 87.25
#   epoch reward:       3.9264/10.9160/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/5.8874/26.6303 [n=170]
#
# 2018-06-22 17:12:58,676 - framestack - INFO: action counts: {0: 309, 1: 103, 2: 1052, 3: 51, 4: 965, 5: 240, 6: 295, 7: 93, 8: 840, 9: 372}
# 2018-06-22 17:12:58,701 - framestack - INFO: steps: 77760, steps/s: 87.11
#   epoch reward:       3.9264/10.9160/26.6303 [n=10] (min/mean/max)
#   running reward:     0.0000/6.1668/26.6303 [n=180]
#
# 2018-06-22 17:13:49,431 - framestack - INFO: action counts: {0: 322, 1: 110, 2: 1048, 3: 76, 4: 980, 5: 249, 6: 289, 7: 92, 8: 808, 9: 346}
# 2018-06-22 17:13:49,460 - framestack - INFO: steps: 82080, steps/s: 87.01
#   epoch reward:       2.0606/9.3798/16.2096 [n=10] (min/mean/max)
#   running reward:     0.0000/6.3359/26.6303 [n=190]
#
# 2018-06-22 17:14:39,427 - framestack - INFO: action counts: {0: 338, 1: 99, 2: 1033, 3: 68, 4: 976, 5: 244, 6: 293, 7: 102, 8: 810, 9: 357}
# 2018-06-22 17:14:39,454 - framestack - INFO: steps: 86400, steps/s: 86.98
#   epoch reward:       2.0606/7.4058/11.6642 [n=10] (min/mean/max)
#   running reward:     0.0000/6.3894/26.6303 [n=200]
#
# 2018-06-22 17:15:29,564 - framestack - INFO: action counts: {0: 340, 1: 109, 2: 1032, 3: 58, 4: 929, 5: 256, 6: 282, 7: 89, 8: 850, 9: 375}
# 2018-06-22 17:15:29,591 - framestack - INFO: steps: 90720, steps/s: 86.94
#   epoch reward:       2.0606/7.4058/11.6642 [n=10] (min/mean/max)
#   running reward:     0.0000/6.4378/26.6303 [n=210]
#
# 2018-06-22 17:16:19,443 - framestack - INFO: action counts: {0: 331, 1: 103, 2: 1023, 3: 75, 4: 907, 5: 257, 6: 279, 7: 119, 8: 839, 9: 387}
# 2018-06-22 17:16:19,470 - framestack - INFO: steps: 95040, steps/s: 86.93
#   epoch reward:       2.0606/9.0736/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.5576/26.6303 [n=220]
#
# 2018-06-22 17:17:08,452 - framestack - INFO: action counts: {0: 316, 1: 95, 2: 1050, 3: 72, 4: 940, 5: 239, 6: 300, 7: 102, 8: 849, 9: 357}
# 2018-06-22 17:17:08,476 - framestack - INFO: steps: 99360, steps/s: 86.98
#   epoch reward:       2.0606/9.0736/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.6670/26.6303 [n=230]
#
# 2018-06-22 17:17:59,136 - framestack - INFO: action counts: {0: 325, 1: 106, 2: 1021, 3: 55, 4: 981, 5: 240, 6: 275, 7: 98, 8: 849, 9: 370}
# 2018-06-22 17:17:59,160 - framestack - INFO: steps: 103680, steps/s: 86.91
#   epoch reward:       2.0606/8.8581/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.7583/26.6303 [n=240]
#
# 2018-06-22 17:18:50,100 - framestack - INFO: action counts: {0: 359, 1: 99, 2: 1009, 3: 73, 4: 923, 5: 247, 6: 302, 7: 94, 8: 835, 9: 379}
# 2018-06-22 17:18:50,127 - framestack - INFO: steps: 108000, steps/s: 86.82
#   epoch reward:       2.0606/8.8581/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.8423/26.6303 [n=250]
# 2018-06-22 17:19:41,007 - framestack - INFO: action counts: {0: 319, 1: 112, 2: 974, 3: 61, 4: 975, 5: 253, 6: 313, 7: 112, 8: 828, 9: 373}
# 2018-06-22 17:19:41,032 - framestack - INFO: steps: 112320, steps/s: 86.74
#   epoch reward:       2.0606/8.7370/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.9152/26.6303 [n=260]
#
# 2018-06-22 17:20:32,032 - framestack - INFO: action counts: {0: 321, 1: 99, 2: 1013, 3: 74, 4: 948, 5: 244, 6: 319, 7: 113, 8: 825, 9: 364}
# 2018-06-22 17:20:32,063 - framestack - INFO: steps: 116640, steps/s: 86.67
#   epoch reward:       2.0606/8.7370/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.9826/26.6303 [n=270]
#
# 2018-06-22 17:21:20,807 - framestack - INFO: action counts: {0: 305, 1: 118, 2: 986, 3: 72, 4: 977, 5: 214, 6: 294, 7: 98, 8: 877, 9: 379}
# 2018-06-22 17:21:20,829 - framestack - INFO: steps: 120960, steps/s: 86.74
#   epoch reward:       2.8419/7.4618/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/6.9997/26.6303 [n=280]
#
# 2018-06-22 17:22:11,473 - framestack - INFO: action counts: {0: 309, 1: 88, 2: 1007, 3: 53, 4: 992, 5: 219, 6: 262, 7: 97, 8: 891, 9: 402}
# 2018-06-22 17:22:11,503 - framestack - INFO: steps: 125280, steps/s: 86.68
#   epoch reward:       2.8419/7.8475/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/7.0290/26.6303 [n=290]
#
# 2018-06-22 17:23:03,414 - framestack - INFO: action counts: {0: 301, 1: 83, 2: 1092, 3: 57, 4: 965, 5: 250, 6: 251, 7: 82, 8: 872, 9: 367}
# 2018-06-22 17:23:03,443 - framestack - INFO: steps: 129600, steps/s: 86.57
#   epoch reward:       2.7332/7.2766/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/7.0372/26.6303 [n=300]
#
# 2018-06-22 17:23:54,738 - framestack - INFO: action counts: {0: 311, 1: 85, 2: 1065, 3: 54, 4: 1014, 5: 223, 6: 268, 7: 82, 8: 845, 9: 373}
# 2018-06-22 17:23:54,764 - framestack - INFO: steps: 133920, steps/s: 86.49
#   epoch reward:       1.9527/6.8292/26.6185 [n=10] (min/mean/max)
#   running reward:     0.0000/7.0305/26.6303 [n=310]
#
# 2018-06-22 17:24:46,335 - framestack - INFO: action counts: {0: 307, 1: 80, 2: 1072, 3: 58, 4: 1014, 5: 203, 6: 251, 7: 68, 8: 921, 9: 346}
# 2018-06-22 17:24:46,359 - framestack - INFO: steps: 138240, steps/s: 86.40
#   epoch reward:       1.9527/4.8191/11.0099 [n=10] (min/mean/max)
#   running reward:     0.0000/6.9614/26.6303 [n=320]
#
# 2018-06-22 17:25:37,406 - framestack - INFO: action counts: {0: 276, 1: 69, 2: 1123, 3: 39, 4: 1028, 5: 182, 6: 258, 7: 65, 8: 967, 9: 313}
# 2018-06-22 17:25:37,432 - framestack - INFO: steps: 142560, steps/s: 86.35
#   epoch reward:       2.7332/7.4550/24.6790 [n=10] (min/mean/max)
#   running reward:     0.0000/6.9764/26.6303 [n=330]
#
# 2018-06-22 17:26:27,329 - framestack - INFO: action counts: {0: 270, 1: 62, 2: 1076, 3: 37, 4: 1088, 5: 219, 6: 214, 7: 61, 8: 937, 9: 356}
# 2018-06-22 17:26:27,353 - framestack - INFO: steps: 146880, steps/s: 86.35
#   epoch reward:       2.7332/7.1105/24.6790 [n=10] (min/mean/max)
#   running reward:     0.0000/6.9803/26.6303 [n=340]
#
# 2018-06-22 17:27:16,072 - framestack - INFO: action counts: {0: 287, 1: 93, 2: 1120, 3: 37, 4: 1015, 5: 207, 6: 217, 7: 69, 8: 953, 9: 322}
# 2018-06-22 17:27:16,096 - framestack - INFO: steps: 151200, steps/s: 86.42
#   epoch reward:       2.7332/10.0084/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.0668/28.3140 [n=350]
#
# 2018-06-22 17:28:07,139 - framestack - INFO: action counts: {0: 266, 1: 95, 2: 1124, 3: 46, 4: 1034, 5: 218, 6: 266, 7: 72, 8: 851, 9: 348}
# 2018-06-22 17:28:07,163 - framestack - INFO: steps: 155520, steps/s: 86.37
#   epoch reward:       2.7332/10.0084/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.1485/28.3140 [n=360]
#
# 2018-06-22 17:28:57,936 - framestack - INFO: action counts: {0: 291, 1: 84, 2: 1097, 3: 40, 4: 998, 5: 207, 6: 239, 7: 77, 8: 935, 9: 352}
# 2018-06-22 17:28:57,958 - framestack - INFO: steps: 159840, steps/s: 86.33
#   epoch reward:       2.7332/10.0084/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.2258/28.3140 [n=370]
#
# 2018-06-22 17:29:49,002 - framestack - INFO: action counts: {0: 266, 1: 75, 2: 1138, 3: 50, 4: 973, 5: 202, 6: 267, 7: 73, 8: 926, 9: 350}
# 2018-06-22 17:29:49,029 - framestack - INFO: steps: 164160, steps/s: 86.29
#   epoch reward:       2.7332/10.6157/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.3150/28.3140 [n=380]
#
# 2018-06-22 17:30:39,796 - framestack - INFO: action counts: {0: 291, 1: 71, 2: 1173, 3: 44, 4: 972, 5: 194, 6: 225, 7: 70, 8: 909, 9: 371}
# 2018-06-22 17:30:39,821 - framestack - INFO: steps: 168480, steps/s: 86.26
#   epoch reward:       3.3070/12.1000/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.4377/28.3140 [n=390]
#
# 2018-06-22 17:31:28,360 - framestack - INFO: action counts: {0: 277, 1: 67, 2: 1151, 3: 31, 4: 1058, 5: 173, 6: 225, 7: 66, 8: 887, 9: 385}
# 2018-06-22 17:31:28,389 - framestack - INFO: steps: 172800, steps/s: 86.32
#   epoch reward:       3.3070/12.1000/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.5543/28.3140 [n=400]
#
# 2018-06-22 17:32:19,706 - framestack - INFO: action counts: {0: 298, 1: 72, 2: 1144, 3: 39, 4: 1021, 5: 174, 6: 233, 7: 56, 8: 939, 9: 344}
# 2018-06-22 17:32:19,732 - framestack - INFO: steps: 177120, steps/s: 86.27
#   epoch reward:       3.3070/13.1291/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.6903/28.3140 [n=410]
#
# 2018-06-22 17:33:10,833 - framestack - INFO: action counts: {0: 270, 1: 80, 2: 1183, 3: 33, 4: 995, 5: 175, 6: 261, 7: 54, 8: 940, 9: 329}
# 2018-06-22 17:33:10,859 - framestack - INFO: steps: 181440, steps/s: 86.23
#   epoch reward:       2.7436/10.8646/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.7658/28.3140 [n=420]
#
# 2018-06-22 17:34:02,013 - framestack - INFO: action counts: {0: 312, 1: 77, 2: 1112, 3: 35, 4: 955, 5: 197, 6: 240, 7: 68, 8: 957, 9: 367}
# 2018-06-22 17:34:02,037 - framestack - INFO: steps: 185760, steps/s: 86.19
#   epoch reward:       2.1401/11.1150/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.8437/28.3140 [n=430]
#
# 2018-06-22 17:34:52,677 - framestack - INFO: action counts: {0: 265, 1: 69, 2: 1201, 3: 37, 4: 988, 5: 192, 6: 249, 7: 71, 8: 909, 9: 339}
# 2018-06-22 17:34:52,699 - framestack - INFO: steps: 190080, steps/s: 86.16
#   epoch reward:       2.1401/12.5696/28.3140 [n=10] (min/mean/max)
#   running reward:     0.0000/7.9511/28.3140 [n=440]
#
# 2018-06-22 17:35:43,684 - framestack - INFO: action counts: {0: 269, 1: 64, 2: 1150, 3: 41, 4: 977, 5: 184, 6: 224, 7: 62, 8: 995, 9: 354}
# 2018-06-22 17:35:43,708 - framestack - INFO: steps: 194400, steps/s: 86.13
#   epoch reward:       2.1401/12.0658/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.0426/28.3140 [n=450]
#
# 2018-06-22 17:36:31,356 - framestack - INFO: action counts: {0: 301, 1: 61, 2: 1102, 3: 41, 4: 1027, 5: 187, 6: 259, 7: 48, 8: 933, 9: 361}
# 2018-06-22 17:36:31,378 - framestack - INFO: steps: 198720, steps/s: 86.23
#   epoch reward:       3.3070/13.1928/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.1545/28.3140 [n=460]
#
# 2018-06-22 17:37:19,979 - framestack - INFO: action counts: {0: 270, 1: 68, 2: 1158, 3: 32, 4: 975, 5: 184, 6: 279, 7: 74, 8: 928, 9: 352}
# 2018-06-22 17:37:20,002 - framestack - INFO: steps: 203040, steps/s: 86.29
#   epoch reward:       1.8440/13.6040/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.2705/28.3140 [n=470]
#
# 2018-06-22 17:38:09,031 - framestack - INFO: action counts: {0: 260, 1: 52, 2: 1210, 3: 40, 4: 1067, 5: 183, 6: 240, 7: 48, 8: 913, 9: 307}
# 2018-06-22 17:38:09,056 - framestack - INFO: steps: 207360, steps/s: 86.32
#   epoch reward:       1.8440/13.6040/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.3816/28.3140 [n=480]
#
# 2018-06-22 17:38:57,788 - framestack - INFO: action counts: {0: 266, 1: 59, 2: 1200, 3: 34, 4: 1041, 5: 182, 6: 206, 7: 51, 8: 960, 9: 321}
# 2018-06-22 17:38:57,814 - framestack - INFO: steps: 211680, steps/s: 86.37
#   epoch reward:       1.8440/13.6040/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.4882/28.3140 [n=490]
#
# 2018-06-22 17:39:47,054 - framestack - INFO: action counts: {0: 246, 1: 67, 2: 1148, 3: 36, 4: 1127, 5: 175, 6: 230, 7: 58, 8: 922, 9: 311}
# 2018-06-22 17:39:47,081 - framestack - INFO: steps: 216000, steps/s: 86.39
#   epoch reward:       1.8440/12.4674/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.5678/28.3140 [n=500]
# 2018-06-22 17:40:36,117 - framestack - INFO: action counts: {0: 290, 1: 76, 2: 1133, 3: 41, 4: 1091, 5: 181, 6: 218, 7: 68, 8: 920, 9: 302}
# 2018-06-22 17:40:36,140 - framestack - INFO: steps: 220320, steps/s: 86.43
#   epoch reward:       1.8440/12.4674/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.7931/28.3140 [n=500]
#
# 2018-06-22 17:41:24,722 - framestack - INFO: action counts: {0: 250, 1: 54, 2: 1177, 3: 32, 4: 1072, 5: 194, 6: 222, 7: 59, 8: 955, 9: 305}
# 2018-06-22 17:41:24,746 - framestack - INFO: steps: 224640, steps/s: 86.47
#   epoch reward:       1.8440/11.5406/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/8.9999/28.3140 [n=500]
#
# 2018-06-22 17:42:12,597 - framestack - INFO: action counts: {0: 252, 1: 76, 2: 1183, 3: 35, 4: 1047, 5: 175, 6: 242, 7: 58, 8: 929, 9: 323}
# 2018-06-22 17:42:12,620 - framestack - INFO: steps: 228960, steps/s: 86.55
#   epoch reward:       1.8440/11.5406/27.9323 [n=10] (min/mean/max)
#   running reward:     0.0000/9.2067/28.3140 [n=500]
#
# 2018-06-22 17:43:01,927 - framestack - INFO: action counts: {0: 238, 1: 64, 2: 1218, 3: 33, 4: 1082, 5: 178, 6: 234, 7: 75, 8: 898, 9: 300}
# 2018-06-22 17:43:01,957 - framestack - INFO: steps: 233280, steps/s: 86.56
#   epoch reward:       1.8440/7.9963/16.0745 [n=10] (min/mean/max)
#   running reward:     0.0000/9.3427/28.3140 [n=500]
#
# 2018-06-22 17:43:51,068 - framestack - INFO: action counts: {0: 261, 1: 63, 2: 1170, 3: 36, 4: 1129, 5: 147, 6: 210, 7: 62, 8: 924, 9: 318}
# 2018-06-22 17:43:51,093 - framestack - INFO: steps: 237600, steps/s: 86.59
#   epoch reward:       1.8440/9.0594/20.7878 [n=10] (min/mean/max)
#   running reward:     0.0000/9.4998/28.3140 [n=500]
#
# 2018-06-22 17:44:39,871 - framestack - INFO: action counts: {0: 255, 1: 59, 2: 1244, 3: 27, 4: 1084, 5: 166, 6: 212, 7: 42, 8: 928, 9: 303}
# 2018-06-22 17:44:39,896 - framestack - INFO: steps: 241920, steps/s: 86.62
#   epoch reward:       1.2232/7.1982/20.7878 [n=10] (min/mean/max)
#   running reward:     0.0000/9.6198/28.3140 [n=500]
#
# 2018-06-22 17:45:29,165 - framestack - INFO: action counts: {0: 239, 1: 48, 2: 1261, 3: 24, 4: 1113, 5: 148, 6: 200, 7: 31, 8: 958, 9: 298}
# 2018-06-22 17:45:29,193 - framestack - INFO: steps: 246240, steps/s: 86.64
#   epoch reward:       2.3168/8.8534/21.2242 [n=10] (min/mean/max)
#   running reward:     0.0000/9.7729/28.3140 [n=500]
#
# 2018-06-22 17:46:18,215 - framestack - INFO: action counts: {0: 218, 1: 46, 2: 1306, 3: 18, 4: 1166, 5: 144, 6: 165, 7: 28, 8: 930, 9: 299}
# 2018-06-22 17:46:18,236 - framestack - INFO: steps: 250560, steps/s: 86.67
#   epoch reward:       2.3168/9.5054/21.2242 [n=10] (min/mean/max)
#   running reward:     0.0000/9.9390/28.3140 [n=500]
#
# 2018-06-22 17:47:06,218 - framestack - INFO: action counts: {0: 211, 1: 29, 2: 1350, 3: 12, 4: 1108, 5: 136, 6: 153, 7: 25, 8: 1014, 9: 282}
# 2018-06-22 17:47:06,244 - framestack - INFO: steps: 254880, steps/s: 86.72
#   epoch reward:       2.3168/9.5054/21.2242 [n=10] (min/mean/max)
#   running reward:     1.2232/10.1051/28.3140 [n=500]
#
# 2018-06-22 17:47:55,648 - framestack - INFO: action counts: {0: 199, 1: 40, 2: 1325, 3: 15, 4: 1168, 5: 138, 6: 156, 7: 30, 8: 948, 9: 301}
# 2018-06-22 17:47:55,672 - framestack - INFO: steps: 259200, steps/s: 86.73
#   epoch reward:       2.3168/9.5054/21.2242 [n=10] (min/mean/max)
#   running reward:     1.2232/10.1083/28.3140 [n=500]
#
# 2018-06-22 17:48:43,448 - framestack - INFO: action counts: {0: 227, 1: 39, 2: 1280, 3: 16, 4: 1143, 5: 130, 6: 198, 7: 40, 8: 954, 9: 293}
# 2018-06-22 17:48:43,471 - framestack - INFO: steps: 263520, steps/s: 86.79
#   epoch reward:       2.3168/10.5242/21.2242 [n=10] (min/mean/max)
#   running reward:     1.2232/10.0659/28.3140 [n=500]
#
# 2018-06-22 17:49:30,614 - framestack - INFO: action counts: {0: 214, 1: 60, 2: 1274, 3: 17, 4: 1104, 5: 154, 6: 181, 7: 41, 8: 989, 9: 286}
# 2018-06-22 17:49:30,636 - framestack - INFO: steps: 267840, steps/s: 86.87
#   epoch reward:       3.2515/11.8323/21.2242 [n=10] (min/mean/max)
#   running reward:     1.2232/10.0813/28.3140 [n=500]
#
# 2018-06-22 17:50:17,529 - framestack - INFO: action counts: {0: 223, 1: 60, 2: 1248, 3: 30, 4: 1107, 5: 168, 6: 217, 7: 61, 8: 905, 9: 301}
# 2018-06-22 17:50:17,550 - framestack - INFO: steps: 272160, steps/s: 86.95
#   epoch reward:       3.2515/11.8323/21.2242 [n=10] (min/mean/max)
#   running reward:     1.2232/10.0831/28.3140 [n=500]
#
# 2018-06-22 17:51:06,385 - framestack - INFO: action counts: {0: 224, 1: 58, 2: 1248, 3: 20, 4: 1082, 5: 151, 6: 219, 7: 53, 8: 947, 9: 318}
# 2018-06-22 17:51:06,407 - framestack - INFO: steps: 276480, steps/s: 86.98
#   epoch reward:       3.9217/13.2505/23.0769 [n=10] (min/mean/max)
#   running reward:     1.2232/10.1132/28.3140 [n=500]
#
# 2018-06-22 17:51:54,069 - framestack - INFO: action counts: {0: 232, 1: 46, 2: 1185, 3: 24, 4: 1144, 5: 156, 6: 217, 7: 48, 8: 972, 9: 296}
# 2018-06-22 17:51:54,091 - framestack - INFO: steps: 280800, steps/s: 87.03
#   epoch reward:       3.9217/14.5866/23.0769 [n=10] (min/mean/max)
#   running reward:     1.2232/10.1866/28.3140 [n=500]
#
# 2018-06-22 17:52:43,199 - framestack - INFO: action counts: {0: 219, 1: 50, 2: 1307, 3: 20, 4: 1106, 5: 131, 6: 171, 7: 60, 8: 958, 9: 298}
# 2018-06-22 17:52:43,223 - framestack - INFO: steps: 285120, steps/s: 87.05
#   epoch reward:       3.3252/13.5857/23.0769 [n=10] (min/mean/max)
#   running reward:     1.2232/10.2400/28.3140 [n=500]
#
# 2018-06-22 17:53:32,505 - framestack - INFO: action counts: {0: 193, 1: 46, 2: 1343, 3: 25, 4: 1082, 5: 135, 6: 193, 7: 42, 8: 978, 9: 283}
# 2018-06-22 17:53:32,527 - framestack - INFO: steps: 289440, steps/s: 87.05
#   epoch reward:       3.3252/13.3663/26.5227 [n=10] (min/mean/max)
#   running reward:     1.2232/10.2890/28.3140 [n=500]
#
# 2018-06-22 17:54:21,066 - framestack - INFO: action counts: {0: 201, 1: 45, 2: 1255, 3: 15, 4: 1176, 5: 132, 6: 174, 7: 38, 8: 994, 9: 290}
# 2018-06-22 17:54:21,092 - framestack - INFO: steps: 293760, steps/s: 87.08
#   epoch reward:       3.3252/13.7892/26.5227 [n=10] (min/mean/max)
#   running reward:     1.2232/10.3465/28.3140 [n=500]
#
# 2018-06-22 17:55:09,602 - framestack - INFO: action counts: {0: 201, 1: 46, 2: 1306, 3: 16, 4: 1123, 5: 113, 6: 176, 7: 45, 8: 1012, 9: 282}
# 2018-06-22 17:55:09,626 - framestack - INFO: steps: 298080, steps/s: 87.11
#   epoch reward:       3.3252/13.7892/26.5227 [n=10] (min/mean/max)
#   running reward:     1.2232/10.4347/28.3140 [n=500]
#
# 2018-06-22 17:55:58,159 - framestack - INFO: action counts: {0: 216, 1: 41, 2: 1393, 3: 17, 4: 1058, 5: 121, 6: 181, 7: 40, 8: 980, 9: 273}
# 2018-06-22 17:55:58,182 - framestack - INFO: steps: 302400, steps/s: 87.14
#   epoch reward:       3.3070/12.7746/26.5227 [n=10] (min/mean/max)
#   running reward:     1.2232/10.5421/28.3140 [n=500]
#
# 2018-06-22 17:56:43,716 - framestack - INFO: action counts: {0: 182, 1: 42, 2: 1324, 3: 28, 4: 1089, 5: 145, 6: 185, 7: 51, 8: 988, 9: 286}
# 2018-06-22 17:56:43,743 - framestack - INFO: steps: 306720, steps/s: 87.24
#   epoch reward:       3.3070/12.6829/26.5227 [n=10] (min/mean/max)
#   running reward:     1.2232/10.6476/28.3140 [n=500]
#
# 2018-06-22 17:57:31,358 - framestack - INFO: action counts: {0: 207, 1: 44, 2: 1342, 3: 26, 4: 1075, 5: 143, 6: 188, 7: 41, 8: 972, 9: 282}
# 2018-06-22 17:57:31,380 - framestack - INFO: steps: 311040, steps/s: 87.29
#   epoch reward:       3.3070/12.6829/26.5227 [n=10] (min/mean/max)
#   running reward:     1.2232/10.7198/28.3140 [n=500]
#
# 2018-06-22 17:58:20,494 - framestack - INFO: action counts: {0: 218, 1: 46, 2: 1245, 3: 24, 4: 1101, 5: 137, 6: 204, 7: 44, 8: 986, 9: 315}
# 2018-06-22 17:58:20,517 - framestack - INFO: steps: 315360, steps/s: 87.30
#   epoch reward:       0.7183/10.4974/26.5227 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7483/28.3140 [n=500]
#
# 2018-06-22 17:59:09,450 - framestack - INFO: action counts: {0: 191, 1: 50, 2: 1255, 3: 27, 4: 1132, 5: 136, 6: 194, 7: 50, 8: 978, 9: 307}
# 2018-06-22 17:59:09,475 - framestack - INFO: steps: 319680, steps/s: 87.31
#   epoch reward:       3.3070/11.4282/26.5227 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7997/28.3140 [n=500]
#
# 2018-06-22 17:59:59,908 - framestack - INFO: action counts: {0: 219, 1: 58, 2: 1244, 3: 32, 4: 1122, 5: 150, 6: 222, 7: 38, 8: 967, 9: 268}
# 2018-06-22 17:59:59,930 - framestack - INFO: steps: 324000, steps/s: 87.29
#   epoch reward:       2.9088/10.7164/26.5227 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8368/28.3140 [n=500]
# 2018-06-22 18:00:48,975 - framestack - INFO: action counts: {0: 211, 1: 55, 2: 1305, 3: 18, 4: 1083, 5: 161, 6: 199, 7: 29, 8: 961, 9: 298}
# 2018-06-22 18:00:49,003 - framestack - INFO: steps: 328320, steps/s: 87.30
#   epoch reward:       2.9088/9.3046/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8482/28.3140 [n=500]
#
# 2018-06-22 18:01:37,013 - framestack - INFO: action counts: {0: 179, 1: 56, 2: 1358, 3: 21, 4: 1071, 5: 117, 6: 186, 7: 39, 8: 1011, 9: 282}
# 2018-06-22 18:01:37,040 - framestack - INFO: steps: 332640, steps/s: 87.34
#   epoch reward:       2.9088/8.8037/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8495/28.3140 [n=500]
#
# 2018-06-22 18:02:25,382 - framestack - INFO: action counts: {0: 194, 1: 44, 2: 1345, 3: 14, 4: 1152, 5: 141, 6: 186, 7: 36, 8: 951, 9: 257}
# 2018-06-22 18:02:25,404 - framestack - INFO: steps: 336960, steps/s: 87.36
#   epoch reward:       2.9088/8.8037/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8763/28.3140 [n=500]
#
# 2018-06-22 18:03:16,532 - framestack - INFO: action counts: {0: 180, 1: 39, 2: 1349, 3: 23, 4: 1162, 5: 146, 6: 149, 7: 37, 8: 968, 9: 267}
# 2018-06-22 18:03:16,556 - framestack - INFO: steps: 341280, steps/s: 87.32
#   epoch reward:       2.9088/8.8037/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8955/28.3140 [n=500]
#
# 2018-06-22 18:04:06,284 - framestack - INFO: action counts: {0: 192, 1: 47, 2: 1269, 3: 24, 4: 1223, 5: 142, 6: 162, 7: 42, 8: 956, 9: 263}
# 2018-06-22 18:04:06,310 - framestack - INFO: steps: 345600, steps/s: 87.32
#   epoch reward:       2.9088/8.7644/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/10.9252/28.3140 [n=500]
#
# 2018-06-22 18:04:55,693 - framestack - INFO: action counts: {0: 191, 1: 59, 2: 1314, 3: 22, 4: 1125, 5: 129, 6: 173, 7: 44, 8: 1003, 9: 260}
# 2018-06-22 18:04:55,717 - framestack - INFO: steps: 349920, steps/s: 87.32
#   epoch reward:       1.8632/8.6082/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/10.9608/28.3140 [n=500]
#
# 2018-06-22 18:05:44,771 - framestack - INFO: action counts: {0: 203, 1: 43, 2: 1248, 3: 18, 4: 1131, 5: 142, 6: 164, 7: 52, 8: 1030, 9: 289}
# 2018-06-22 18:05:44,799 - framestack - INFO: steps: 354240, steps/s: 87.33
#   epoch reward:       2.9088/9.5870/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/11.0562/28.3140 [n=500]
#
# 2018-06-22 18:06:32,629 - framestack - INFO: action counts: {0: 177, 1: 59, 2: 1251, 3: 13, 4: 1093, 5: 145, 6: 180, 7: 45, 8: 1043, 9: 314}
# 2018-06-22 18:06:32,655 - framestack - INFO: steps: 358560, steps/s: 87.36
#   epoch reward:       2.9088/9.5870/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/11.0988/28.3140 [n=500]
#
# 2018-06-22 18:07:20,853 - framestack - INFO: action counts: {0: 194, 1: 60, 2: 1243, 3: 36, 4: 1093, 5: 137, 6: 190, 7: 39, 8: 1031, 9: 297}
# 2018-06-22 18:07:20,881 - framestack - INFO: steps: 362880, steps/s: 87.39
#   epoch reward:       3.0177/10.1851/26.1445 [n=10] (min/mean/max)
#   running reward:     0.7183/11.1603/28.3140 [n=500]
#
# 2018-06-22 18:08:10,462 - framestack - INFO: action counts: {0: 214, 1: 57, 2: 1231, 3: 27, 4: 1126, 5: 157, 6: 168, 7: 42, 8: 997, 9: 301}
# 2018-06-22 18:08:10,481 - framestack - INFO: steps: 367200, steps/s: 87.39
#   epoch reward:       3.0177/10.7395/26.6185 [n=10] (min/mean/max)
#   running reward:     0.7183/11.1749/28.3140 [n=500]
#
# 2018-06-22 18:08:59,798 - framestack - INFO: action counts: {0: 182, 1: 40, 2: 1255, 3: 17, 4: 1171, 5: 136, 6: 166, 7: 55, 8: 1013, 9: 285}
# 2018-06-22 18:08:59,823 - framestack - INFO: steps: 371520, steps/s: 87.39
#   epoch reward:       2.1237/8.4329/17.1469 [n=10] (min/mean/max)
#   running reward:     0.7183/11.1434/28.3140 [n=500]
#
# 2018-06-22 18:09:48,713 - framestack - INFO: action counts: {0: 194, 1: 46, 2: 1239, 3: 18, 4: 1153, 5: 150, 6: 171, 7: 37, 8: 1034, 9: 278}
# 2018-06-22 18:09:48,739 - framestack - INFO: steps: 375840, steps/s: 87.40
#   epoch reward:       2.1237/8.4329/17.1469 [n=10] (min/mean/max)
#   running reward:     0.7183/11.1119/28.3140 [n=500]
#
# 2018-06-22 18:10:38,027 - framestack - INFO: action counts: {0: 207, 1: 53, 2: 1248, 3: 15, 4: 1109, 5: 128, 6: 172, 7: 30, 8: 1057, 9: 301}
# 2018-06-22 18:10:38,050 - framestack - INFO: steps: 380160, steps/s: 87.40
#   epoch reward:       2.1237/8.4329/17.1469 [n=10] (min/mean/max)
#   running reward:     0.7183/11.0682/28.3140 [n=500]
#
# 2018-06-22 18:11:26,157 - framestack - INFO: action counts: {0: 179, 1: 48, 2: 1270, 3: 22, 4: 1098, 5: 160, 6: 156, 7: 43, 8: 1064, 9: 280}
# 2018-06-22 18:11:26,180 - framestack - INFO: steps: 384480, steps/s: 87.43
#   epoch reward:       2.1237/8.9760/17.1469 [n=10] (min/mean/max)
#   running reward:     0.7183/11.0058/28.3140 [n=500]
#
# 2018-06-22 18:12:14,122 - framestack - INFO: action counts: {0: 215, 1: 50, 2: 1279, 3: 27, 4: 1123, 5: 142, 6: 167, 7: 57, 8: 965, 9: 295}
# 2018-06-22 18:12:14,145 - framestack - INFO: steps: 388800, steps/s: 87.46
#   epoch reward:       2.1237/8.9760/17.1469 [n=10] (min/mean/max)
#   running reward:     0.7183/10.9433/28.3140 [n=500]
#
# 2018-06-22 18:13:03,200 - framestack - INFO: action counts: {0: 200, 1: 50, 2: 1217, 3: 24, 4: 1121, 5: 157, 6: 202, 7: 48, 8: 991, 9: 310}
# 2018-06-22 18:13:03,224 - framestack - INFO: steps: 393120, steps/s: 87.46
#   epoch reward:       2.1237/8.0422/17.1469 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8416/28.3140 [n=500]
#
# 2018-06-22 18:13:52,525 - framestack - INFO: action counts: {0: 177, 1: 48, 2: 1201, 3: 30, 4: 1075, 5: 162, 6: 185, 7: 50, 8: 1080, 9: 312}
# 2018-06-22 18:13:52,548 - framestack - INFO: steps: 397440, steps/s: 87.46
#   epoch reward:       2.1237/10.0886/23.4810 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8260/28.3140 [n=500]
#
# 2018-06-22 18:14:42,487 - framestack - INFO: action counts: {0: 178, 1: 44, 2: 1257, 3: 23, 4: 1164, 5: 165, 6: 175, 7: 44, 8: 1005, 9: 265}
# 2018-06-22 18:14:42,512 - framestack - INFO: steps: 401760, steps/s: 87.45
#   epoch reward:       2.1237/10.0886/23.4810 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8055/28.3140 [n=500]
#
# 2018-06-22 18:15:31,797 - framestack - INFO: action counts: {0: 202, 1: 57, 2: 1221, 3: 19, 4: 1177, 5: 147, 6: 192, 7: 48, 8: 975, 9: 282}
# 2018-06-22 18:15:31,818 - framestack - INFO: steps: 406080, steps/s: 87.46
#   epoch reward:       2.1237/10.0737/23.4810 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7556/27.9323 [n=500]
#
# 2018-06-22 18:16:21,417 - framestack - INFO: action counts: {0: 223, 1: 42, 2: 1218, 3: 21, 4: 1175, 5: 148, 6: 180, 7: 44, 8: 965, 9: 304}
# 2018-06-22 18:16:21,439 - framestack - INFO: steps: 410400, steps/s: 87.45
#   epoch reward:       3.2713/13.8796/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7919/45.7083 [n=500]
#
# 2018-06-22 18:17:08,617 - framestack - INFO: action counts: {0: 208, 1: 57, 2: 1234, 3: 28, 4: 1103, 5: 155, 6: 219, 7: 49, 8: 958, 9: 309}
# 2018-06-22 18:17:08,641 - framestack - INFO: steps: 414720, steps/s: 87.49
#   epoch reward:       3.2713/13.2274/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7926/45.7083 [n=500]
#
# 2018-06-22 18:17:56,684 - framestack - INFO: action counts: {0: 197, 1: 43, 2: 1211, 3: 18, 4: 1181, 5: 152, 6: 188, 7: 58, 8: 949, 9: 323}
# 2018-06-22 18:17:56,709 - framestack - INFO: steps: 419040, steps/s: 87.52
#   epoch reward:       3.2713/13.2274/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7850/45.7083 [n=500]
#
# 2018-06-22 18:18:44,890 - framestack - INFO: action counts: {0: 202, 1: 37, 2: 1261, 3: 21, 4: 1230, 5: 148, 6: 177, 7: 41, 8: 932, 9: 271}
# 2018-06-22 18:18:44,915 - framestack - INFO: steps: 423360, steps/s: 87.54
#   epoch reward:       3.2713/13.1019/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7750/45.7083 [n=500]
#
# 2018-06-22 18:19:32,900 - framestack - INFO: action counts: {0: 248, 1: 50, 2: 1219, 3: 22, 4: 1160, 5: 155, 6: 184, 7: 52, 8: 921, 9: 309}
# 2018-06-22 18:19:32,927 - framestack - INFO: steps: 427680, steps/s: 87.56
#   epoch reward:       3.2713/12.1956/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7468/45.7083 [n=500]
#
# 2018-06-22 18:20:21,714 - framestack - INFO: action counts: {0: 226, 1: 44, 2: 1218, 3: 22, 4: 1138, 5: 156, 6: 204, 7: 53, 8: 970, 9: 289}
# 2018-06-22 18:20:21,739 - framestack - INFO: steps: 432000, steps/s: 87.57
#   epoch reward:       3.2713/12.1956/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7414/45.7083 [n=500]
#
# 2018-06-22 18:21:09,543 - framestack - INFO: action counts: {0: 258, 1: 54, 2: 1214, 3: 25, 4: 1172, 5: 140, 6: 190, 7: 46, 8: 915, 9: 306}
# 2018-06-22 18:21:09,570 - framestack - INFO: steps: 436320, steps/s: 87.60
#   epoch reward:       3.2713/13.2667/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7574/45.7083 [n=500]
#
# 2018-06-22 18:21:56,162 - framestack - INFO: action counts: {0: 229, 1: 47, 2: 1208, 3: 30, 4: 1171, 5: 165, 6: 203, 7: 45, 8: 932, 9: 290}
# 2018-06-22 18:21:56,190 - framestack - INFO: steps: 440640, steps/s: 87.65
#   epoch reward:       5.1114/14.2116/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8108/45.7083 [n=500]
#
# 2018-06-22 18:22:41,961 - framestack - INFO: action counts: {0: 230, 1: 38, 2: 1224, 3: 26, 4: 1159, 5: 154, 6: 210, 7: 44, 8: 940, 9: 295}
# 2018-06-22 18:22:41,985 - framestack - INFO: steps: 444960, steps/s: 87.72
#   epoch reward:       2.1292/11.5778/45.7083 [n=10] (min/mean/max)
#   running reward:     0.7183/10.8115/45.7083 [n=500]
#
# 2018-06-22 18:23:27,324 - framestack - INFO: action counts: {0: 193, 1: 48, 2: 1273, 3: 30, 4: 1231, 5: 112, 6: 189, 7: 46, 8: 888, 9: 310}
# 2018-06-22 18:23:27,346 - framestack - INFO: steps: 449280, steps/s: 87.79
#   epoch reward:       1.3836/7.0875/13.5727 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7934/45.7083 [n=500]
#
# 2018-06-22 18:24:13,525 - framestack - INFO: action counts: {0: 260, 1: 42, 2: 1254, 3: 28, 4: 1183, 5: 115, 6: 171, 7: 49, 8: 929, 9: 289}
# 2018-06-22 18:24:13,551 - framestack - INFO: steps: 453600, steps/s: 87.84
#   epoch reward:       1.3836/6.7974/13.0596 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7481/45.7083 [n=500]
#
# 2018-06-22 18:24:58,753 - framestack - INFO: action counts: {0: 241, 1: 37, 2: 1318, 3: 18, 4: 1207, 5: 130, 6: 153, 7: 39, 8: 863, 9: 314}
# 2018-06-22 18:24:58,782 - framestack - INFO: steps: 457920, steps/s: 87.91
#   epoch reward:       1.3836/8.5367/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7749/45.7083 [n=500]
#
# 2018-06-22 18:25:45,509 - framestack - INFO: action counts: {0: 249, 1: 41, 2: 1294, 3: 17, 4: 1154, 5: 123, 6: 164, 7: 35, 8: 938, 9: 305}
# 2018-06-22 18:25:45,537 - framestack - INFO: steps: 462240, steps/s: 87.96
#   epoch reward:       1.3836/8.0785/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7594/45.7083 [n=500]
#
# 2018-06-22 18:26:31,534 - framestack - INFO: action counts: {0: 242, 1: 57, 2: 1183, 3: 13, 4: 1226, 5: 144, 6: 183, 7: 53, 8: 912, 9: 307}
# 2018-06-22 18:26:31,559 - framestack - INFO: steps: 466560, steps/s: 88.01
#   epoch reward:       1.3836/8.7143/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7436/45.7083 [n=500]
#
# 2018-06-22 18:27:17,393 - framestack - INFO: action counts: {0: 252, 1: 57, 2: 1237, 3: 18, 4: 1148, 5: 143, 6: 175, 7: 59, 8: 938, 9: 293}
# 2018-06-22 18:27:17,416 - framestack - INFO: steps: 470880, steps/s: 88.07
#   epoch reward:       1.3836/8.7143/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7277/45.7083 [n=500]
#
# 2018-06-22 18:28:02,470 - framestack - INFO: action counts: {0: 254, 1: 57, 2: 1225, 3: 28, 4: 1111, 5: 165, 6: 190, 7: 63, 8: 915, 9: 312}
# 2018-06-22 18:28:02,492 - framestack - INFO: steps: 475200, steps/s: 88.14
#   epoch reward:       1.3836/8.4691/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.7070/45.7083 [n=500]
#
# 2018-06-22 18:28:48,710 - framestack - INFO: action counts: {0: 241, 1: 52, 2: 1252, 3: 30, 4: 1111, 5: 146, 6: 180, 7: 40, 8: 948, 9: 320}
# 2018-06-22 18:28:48,735 - framestack - INFO: steps: 479520, steps/s: 88.19
#   epoch reward:       1.3836/6.0873/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.6183/45.7083 [n=500]
#
# 2018-06-22 18:29:33,913 - framestack - INFO: action counts: {0: 241, 1: 49, 2: 1195, 3: 26, 4: 1213, 5: 156, 6: 179, 7: 52, 8: 942, 9: 267}
# 2018-06-22 18:29:33,936 - framestack - INFO: steps: 483840, steps/s: 88.25
#   epoch reward:       1.3836/6.1031/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.5037/45.7083 [n=500]
#
# 2018-06-22 18:30:20,255 - framestack - INFO: action counts: {0: 258, 1: 53, 2: 1269, 3: 27, 4: 1119, 5: 128, 6: 169, 7: 44, 8: 940, 9: 313}
# 2018-06-22 18:30:20,280 - framestack - INFO: steps: 488160, steps/s: 88.30
#   epoch reward:       1.3836/5.9755/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.3866/45.7083 [n=500]
#
# 2018-06-22 18:31:04,903 - framestack - INFO: action counts: {0: 251, 1: 47, 2: 1253, 3: 22, 4: 1138, 5: 132, 6: 176, 7: 41, 8: 993, 9: 267}
# 2018-06-22 18:31:04,929 - framestack - INFO: steps: 492480, steps/s: 88.37
#   epoch reward:       1.9854/6.5062/22.5044 [n=10] (min/mean/max)
#   running reward:     0.7183/10.2517/45.7083 [n=500]
#
# 2018-06-22 18:31:49,459 - framestack - INFO: action counts: {0: 226, 1: 45, 2: 1226, 3: 20, 4: 1176, 5: 142, 6: 160, 7: 47, 8: 1012, 9: 266}
# 2018-06-22 18:31:49,482 - framestack - INFO: steps: 496800, steps/s: 88.44
#   epoch reward:       1.9854/6.3402/18.0391 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0867/45.7083 [n=500]
#
# 2018-06-22 18:32:34,418 - framestack - INFO: action counts: {0: 240, 1: 46, 2: 1164, 3: 28, 4: 1145, 5: 144, 6: 197, 7: 39, 8: 1022, 9: 295}
# 2018-06-22 18:32:34,441 - framestack - INFO: steps: 501120, steps/s: 88.51
#   epoch reward:       1.9854/5.1720/12.2991 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9185/45.7083 [n=500]
#
# 2018-06-22 18:33:20,805 - framestack - INFO: action counts: {0: 273, 1: 35, 2: 1272, 3: 21, 4: 1086, 5: 171, 6: 179, 7: 49, 8: 954, 9: 280}
# 2018-06-22 18:33:20,829 - framestack - INFO: steps: 505440, steps/s: 88.55
#   epoch reward:       1.9893/6.3208/12.3295 [n=10] (min/mean/max)
#   running reward:     0.7183/9.7776/45.7083 [n=500]
#
# 2018-06-22 18:34:06,148 - framestack - INFO: action counts: {0: 227, 1: 45, 2: 1216, 3: 30, 4: 1160, 5: 162, 6: 174, 7: 51, 8: 975, 9: 280}
# 2018-06-22 18:34:06,176 - framestack - INFO: steps: 509760, steps/s: 88.61
#   epoch reward:       1.9893/5.8570/12.3295 [n=10] (min/mean/max)
#   running reward:     0.7183/9.6189/45.7083 [n=500]
#
# 2018-06-22 18:34:51,274 - framestack - INFO: action counts: {0: 243, 1: 53, 2: 1223, 3: 21, 4: 1169, 5: 137, 6: 167, 7: 41, 8: 1005, 9: 261}
# 2018-06-22 18:34:51,298 - framestack - INFO: steps: 514080, steps/s: 88.67
#   epoch reward:       1.9893/10.7197/46.7847 [n=10] (min/mean/max)
#   running reward:     0.7183/9.5575/46.7847 [n=500]
#
# 2018-06-22 18:35:36,405 - framestack - INFO: action counts: {0: 244, 1: 45, 2: 1242, 3: 20, 4: 1104, 5: 157, 6: 170, 7: 45, 8: 988, 9: 305}
# 2018-06-22 18:35:36,429 - framestack - INFO: steps: 518400, steps/s: 88.73
#   epoch reward:       2.0853/14.0292/46.7847 [n=10] (min/mean/max)
#   running reward:     0.7183/9.5826/46.7847 [n=500]
#
# 2018-06-22 18:36:21,812 - framestack - INFO: action counts: {0: 232, 1: 63, 2: 1243, 3: 19, 4: 1149, 5: 121, 6: 154, 7: 42, 8: 1058, 9: 239}
# 2018-06-22 18:36:21,834 - framestack - INFO: steps: 522720, steps/s: 88.78
#   epoch reward:       2.0853/14.3625/46.7847 [n=10] (min/mean/max)
#   running reward:     0.7183/9.6162/46.7847 [n=500]
#
# 2018-06-22 18:37:08,884 - framestack - INFO: action counts: {0: 251, 1: 52, 2: 1213, 3: 31, 4: 1121, 5: 146, 6: 161, 7: 42, 8: 1009, 9: 294}
# 2018-06-22 18:37:08,909 - framestack - INFO: steps: 527040, steps/s: 88.80
#   epoch reward:       1.8836/13.9853/46.7847 [n=10] (min/mean/max)
#   running reward:     0.7183/9.6423/46.7847 [n=500]
#
# 2018-06-22 18:37:54,578 - framestack - INFO: action counts: {0: 253, 1: 54, 2: 1196, 3: 23, 4: 1074, 5: 128, 6: 189, 7: 49, 8: 1040, 9: 314}
# 2018-06-22 18:37:54,603 - framestack - INFO: steps: 531360, steps/s: 88.85
#   epoch reward:       1.8836/14.6937/46.7847 [n=10] (min/mean/max)
#   running reward:     1.3836/9.7262/46.7847 [n=500]
#
# 2018-06-22 18:38:40,341 - framestack - INFO: action counts: {0: 252, 1: 50, 2: 1209, 3: 22, 4: 1128, 5: 143, 6: 175, 7: 51, 8: 980, 9: 310}
# 2018-06-22 18:38:40,367 - framestack - INFO: steps: 535680, steps/s: 88.89
#   epoch reward:       1.8836/14.6937/46.7847 [n=10] (min/mean/max)
#   running reward:     1.3836/9.7915/46.7847 [n=500]
# 2018-06-22 18:39:25,817 - framestack - INFO: action counts: {0: 257, 1: 61, 2: 1211, 3: 23, 4: 1088, 5: 144, 6: 208, 7: 51, 8: 960, 9: 317}
# 2018-06-22 18:39:25,839 - framestack - INFO: steps: 540000, steps/s: 88.94
#   epoch reward:       1.8836/15.3900/46.7847 [n=10] (min/mean/max)
#   running reward:     1.3836/9.8850/46.7847 [n=500]
#
# 2018-06-22 18:40:11,840 - framestack - INFO: action counts: {0: 295, 1: 70, 2: 1146, 3: 34, 4: 1065, 5: 170, 6: 203, 7: 53, 8: 946, 9: 338}
# 2018-06-22 18:40:11,865 - framestack - INFO: steps: 544320, steps/s: 88.98
#   epoch reward:       1.8836/14.6341/46.7847 [n=10] (min/mean/max)
#   running reward:     1.3836/9.9916/46.7847 [n=500]
#
# 2018-06-22 18:40:57,046 - framestack - INFO: action counts: {0: 268, 1: 74, 2: 1153, 3: 13, 4: 1068, 5: 164, 6: 187, 7: 68, 8: 993, 9: 332}
# 2018-06-22 18:40:57,070 - framestack - INFO: steps: 548640, steps/s: 89.03
#   epoch reward:       0.7183/13.5595/46.7847 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0867/46.7847 [n=500]
#
# 2018-06-22 18:41:42,933 - framestack - INFO: action counts: {0: 278, 1: 74, 2: 1146, 3: 35, 4: 1016, 5: 198, 6: 224, 7: 75, 8: 967, 9: 307}
# 2018-06-22 18:41:42,958 - framestack - INFO: steps: 552960, steps/s: 89.07
#   epoch reward:       0.7183/8.9387/22.4872 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0894/46.7847 [n=500]
#
# 2018-06-22 18:42:30,264 - framestack - INFO: action counts: {0: 304, 1: 72, 2: 1090, 3: 34, 4: 1008, 5: 193, 6: 220, 7: 75, 8: 1028, 9: 296}
# 2018-06-22 18:42:30,290 - framestack - INFO: steps: 557280, steps/s: 89.09
#   epoch reward:       1.8836/7.6338/13.3190 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0660/46.7847 [n=500]
#
# 2018-06-22 18:43:18,518 - framestack - INFO: action counts: {0: 299, 1: 71, 2: 1080, 3: 35, 4: 1027, 5: 195, 6: 207, 7: 63, 8: 1042, 9: 301}
# 2018-06-22 18:43:18,541 - framestack - INFO: steps: 561600, steps/s: 89.09
#   epoch reward:       1.8836/7.6338/13.3190 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0434/46.7847 [n=500]
#
# 2018-06-22 18:44:04,847 - framestack - INFO: action counts: {0: 295, 1: 82, 2: 1122, 3: 34, 4: 1030, 5: 197, 6: 194, 7: 69, 8: 974, 9: 323}
# 2018-06-22 18:44:04,871 - framestack - INFO: steps: 565920, steps/s: 89.13
#   epoch reward:       2.2248/8.8859/14.4051 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0489/46.7847 [n=500]
#
# 2018-06-22 18:44:50,951 - framestack - INFO: action counts: {0: 308, 1: 81, 2: 1116, 3: 53, 4: 987, 5: 170, 6: 221, 7: 81, 8: 997, 9: 306}
# 2018-06-22 18:44:50,973 - framestack - INFO: steps: 570240, steps/s: 89.16
#   epoch reward:       2.2248/8.0854/13.3190 [n=10] (min/mean/max)
#   running reward:     0.7183/10.0189/46.7847 [n=500]
#
# 2018-06-22 18:45:37,665 - framestack - INFO: action counts: {0: 294, 1: 60, 2: 1128, 3: 29, 4: 963, 5: 171, 6: 221, 7: 81, 8: 1067, 9: 306}
# 2018-06-22 18:45:37,687 - framestack - INFO: steps: 574560, steps/s: 89.19
#   epoch reward:       2.2248/8.0854/13.3190 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9889/46.7847 [n=500]
#
# 2018-06-22 18:46:22,417 - framestack - INFO: action counts: {0: 289, 1: 72, 2: 1027, 3: 50, 4: 1050, 5: 180, 6: 232, 7: 67, 8: 1035, 9: 318}
# 2018-06-22 18:46:22,438 - framestack - INFO: steps: 578880, steps/s: 89.24
#   epoch reward:       2.2248/8.0854/13.3190 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9469/46.7847 [n=500]
#
# 2018-06-22 18:47:07,439 - framestack - INFO: action counts: {0: 332, 1: 79, 2: 1057, 3: 43, 4: 958, 5: 181, 6: 246, 7: 75, 8: 945, 9: 404}
# 2018-06-22 18:47:07,457 - framestack - INFO: steps: 583200, steps/s: 89.29
#   epoch reward:       2.2248/8.4312/16.7771 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9007/46.7847 [n=500]
#
# 2018-06-22 18:47:53,672 - framestack - INFO: action counts: {0: 282, 1: 84, 2: 1136, 3: 40, 4: 941, 5: 187, 6: 243, 7: 89, 8: 999, 9: 319}
# 2018-06-22 18:47:53,696 - framestack - INFO: steps: 587520, steps/s: 89.32
#   epoch reward:       2.7224/9.2812/16.7771 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9177/46.7847 [n=500]
#
# 2018-06-22 18:48:39,178 - framestack - INFO: action counts: {0: 317, 1: 73, 2: 1127, 3: 44, 4: 995, 5: 173, 6: 236, 7: 78, 8: 963, 9: 314}
# 2018-06-22 18:48:39,201 - framestack - INFO: steps: 591840, steps/s: 89.36
#   epoch reward:       2.7224/9.3668/16.7771 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9363/46.7847 [n=500]
#
# 2018-06-22 18:49:25,598 - framestack - INFO: action counts: {0: 293, 1: 80, 2: 1081, 3: 28, 4: 1060, 5: 153, 6: 205, 7: 67, 8: 1055, 9: 298}
# 2018-06-22 18:49:25,623 - framestack - INFO: steps: 596160, steps/s: 89.39
#   epoch reward:       2.7224/9.8435/25.2935 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9645/46.7847 [n=500]
#
# 2018-06-22 18:50:12,355 - framestack - INFO: action counts: {0: 258, 1: 53, 2: 1188, 3: 26, 4: 1016, 5: 181, 6: 199, 7: 46, 8: 1033, 9: 320}
# 2018-06-22 18:50:12,384 - framestack - INFO: steps: 600480, steps/s: 89.41
#   epoch reward:       2.7224/8.2526/16.7771 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9501/46.7847 [n=500]
#
# 2018-06-22 18:50:58,155 - framestack - INFO: action counts: {0: 299, 1: 47, 2: 1207, 3: 17, 4: 1027, 5: 157, 6: 182, 7: 36, 8: 1059, 9: 289}
# 2018-06-22 18:50:58,178 - framestack - INFO: steps: 604800, steps/s: 89.45
#   epoch reward:       2.7224/8.1782/16.7771 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9341/46.7847 [n=500]
#
# 2018-06-22 18:51:44,102 - framestack - INFO: action counts: {0: 312, 1: 55, 2: 1160, 3: 29, 4: 1029, 5: 133, 6: 170, 7: 56, 8: 1040, 9: 336}
# 2018-06-22 18:51:44,125 - framestack - INFO: steps: 609120, steps/s: 89.48
#   epoch reward:       2.9223/8.2988/16.7771 [n=10] (min/mean/max)
#   running reward:     0.7183/9.9393/46.7847 [n=500]
#
# 2018-06-22 18:52:31,252 - framestack - INFO: action counts: {0: 296, 1: 75, 2: 1116, 3: 25, 4: 1018, 5: 172, 6: 190, 7: 46, 8: 1039, 9: 343}
# 2018-06-22 18:52:31,276 - framestack - INFO: steps: 613440, steps/s: 89.49
#   epoch reward:       0.1048/7.9788/16.7771 [n=10] (min/mean/max)
#   running reward:     0.1048/9.8971/46.7847 [n=500]
#
# 2018-06-22 18:53:18,171 - framestack - INFO: action counts: {0: 295, 1: 49, 2: 1108, 3: 20, 4: 1043, 5: 169, 6: 209, 7: 79, 8: 1031, 9: 317}
# 2018-06-22 18:53:18,196 - framestack - INFO: steps: 617760, steps/s: 89.51
#   epoch reward:       0.1048/11.4938/47.3544 [n=10] (min/mean/max)
#   running reward:     0.1048/9.9252/47.3544 [n=500]
#
# 2018-06-22 18:54:04,925 - framestack - INFO: action counts: {0: 298, 1: 49, 2: 1138, 3: 30, 4: 1069, 5: 171, 6: 182, 7: 53, 8: 1026, 9: 304}
# ...
# 2018-06-23 15:50:43,597 - framestack - INFO: steps: 7706880, steps/s: 93.96
#   epoch reward:       0.5580/6.9940/22.4872 [n=10] (min/mean/max)
#   running reward:     0.5580/10.8159/47.2714 [n=500]
#
# 2018-06-23 15:51:30,371 - framestack - INFO: action counts: {0: 276, 1: 47, 2: 915, 3: 44, 4: 998, 5: 97, 6: 128, 7: 67, 8: 1362, 9: 386}
# 2018-06-23 15:51:30,397 - framestack - INFO: steps: 7711200, steps/s: 93.96
#   epoch reward:       0.5580/6.9940/22.4872 [n=10] (min/mean/max)
#   running reward:     0.5580/10.6556/47.2714 [n=500]
#
# 2018-06-23 15:52:13,732 - framestack - INFO: action counts: {0: 244, 1: 51, 2: 948, 3: 34, 4: 980, 5: 92, 6: 151, 7: 62, 8: 1347, 9: 411}
# 2018-06-23 15:52:13,760 - framestack - INFO: steps: 7715520, steps/s: 93.97
#   epoch reward:       0.5580/8.5452/22.4872 [n=10] (min/mean/max)
#   running reward:     0.5580/10.5418/47.2714 [n=500]
#
# 2018-06-23 15:53:00,699 - framestack - INFO: action counts: {0: 253, 1: 43, 2: 907, 3: 27, 4: 1061, 5: 101, 6: 99, 7: 64, 8: 1392, 9: 373}
# 2018-06-23 15:53:00,721 - framestack - INFO: steps: 7719840, steps/s: 93.97
#   epoch reward:       0.5580/8.3015/22.4872 [n=10] (min/mean/max)
#   running reward:     0.5580/10.4135/47.2714 [n=500]
#
# 2018-06-23 15:53:45,542 - framestack - INFO: action counts: {0: 217, 1: 40, 2: 917, 3: 30, 4: 1041, 5: 88, 6: 120, 7: 62, 8: 1430, 9: 375}
# 2018-06-23 15:53:45,565 - framestack - INFO: steps: 7724160, steps/s: 93.97
#   epoch reward:       0.4673/9.7107/22.4872 [n=10] (min/mean/max)
#   running reward:     0.4673/10.3239/47.2714 [n=500]
#
# 2018-06-23 15:54:31,281 - framestack - INFO: action counts: {0: 209, 1: 30, 2: 966, 3: 30, 4: 1064, 5: 72, 6: 120, 7: 41, 8: 1407, 9: 381}
# 2018-06-23 15:54:31,306 - framestack - INFO: steps: 7728480, steps/s: 93.97
#   epoch reward:       0.4673/7.8201/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/10.1953/47.2714 [n=500]
#
# 2018-06-23 15:55:17,349 - framestack - INFO: action counts: {0: 243, 1: 33, 2: 983, 3: 38, 4: 995, 5: 78, 6: 104, 7: 59, 8: 1417, 9: 370}
# 2018-06-23 15:55:17,373 - framestack - INFO: steps: 7732800, steps/s: 93.97
#   epoch reward:       0.4673/7.8201/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/10.0667/47.2714 [n=500]
#
# 2018-06-23 15:56:02,844 - framestack - INFO: action counts: {0: 210, 1: 33, 2: 918, 3: 33, 4: 1053, 5: 90, 6: 146, 7: 69, 8: 1376, 9: 392}
# 2018-06-23 15:56:02,869 - framestack - INFO: steps: 7737120, steps/s: 93.97
#   epoch reward:       0.4673/8.5522/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/9.9527/47.2714 [n=500]
#
# 2018-06-23 15:56:48,514 - framestack - INFO: action counts: {0: 238, 1: 32, 2: 940, 3: 34, 4: 1043, 5: 86, 6: 116, 7: 46, 8: 1412, 9: 373}
# 2018-06-23 15:56:48,538 - framestack - INFO: steps: 7741440, steps/s: 93.97
#   epoch reward:       0.4673/9.2782/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/9.8532/30.1345 [n=500]
#
# 2018-06-23 15:57:36,246 - framestack - INFO: action counts: {0: 214, 1: 30, 2: 947, 3: 38, 4: 1046, 5: 86, 6: 124, 7: 61, 8: 1440, 9: 334}
# 2018-06-23 15:57:36,274 - framestack - INFO: steps: 7745760, steps/s: 93.96
#   epoch reward:       3.6952/10.1109/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/9.8221/30.1345 [n=500]
#
# 2018-06-23 15:58:20,882 - framestack - INFO: action counts: {0: 199, 1: 32, 2: 1028, 3: 20, 4: 1044, 5: 73, 6: 104, 7: 45, 8: 1419, 9: 356}
# 2018-06-23 15:58:20,907 - framestack - INFO: steps: 7750080, steps/s: 93.97
#   epoch reward:       3.6952/9.9278/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/9.7874/30.1345 [n=500]
#
# 2018-06-23 15:59:06,620 - framestack - INFO: action counts: {0: 232, 1: 42, 2: 990, 3: 36, 4: 1056, 5: 73, 6: 103, 7: 54, 8: 1381, 9: 353}
# 2018-06-23 15:59:06,651 - framestack - INFO: steps: 7754400, steps/s: 93.97
#   epoch reward:       3.6952/13.3675/30.8297 [n=10] (min/mean/max)
#   running reward:     0.4673/9.8226/30.8297 [n=500]
#
# 2018-06-23 15:59:54,720 - framestack - INFO: action counts: {0: 254, 1: 43, 2: 928, 3: 32, 4: 1046, 5: 89, 6: 111, 7: 47, 8: 1420, 9: 350}
# 2018-06-23 15:59:54,745 - framestack - INFO: steps: 7758720, steps/s: 93.96
#   epoch reward:       3.6952/11.1512/30.8297 [n=10] (min/mean/max)
#   running reward:     0.4673/9.8243/30.8297 [n=500]
#
# 2018-06-23 16:00:39,799 - framestack - INFO: action counts: {0: 235, 1: 40, 2: 963, 3: 29, 4: 968, 5: 101, 6: 153, 7: 54, 8: 1360, 9: 417}
# 2018-06-23 16:00:39,829 - framestack - INFO: steps: 7763040, steps/s: 93.97
#   epoch reward:       3.0624/11.0318/17.5773 [n=10] (min/mean/max)
#   running reward:     0.4673/9.8134/30.8297 [n=500]
# 2018-06-23 16:01:24,161 - framestack - INFO: action counts: {0: 254, 1: 58, 2: 904, 3: 42, 4: 946, 5: 89, 6: 123, 7: 71, 8: 1438, 9: 395}
# 2018-06-23 16:01:24,192 - framestack - INFO: steps: 7767360, steps/s: 93.97
#   epoch reward:       3.0624/8.8993/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/9.7741/30.8297 [n=500]
#
# 2018-06-23 16:02:09,245 - framestack - INFO: action counts: {0: 216, 1: 36, 2: 981, 3: 28, 4: 1019, 5: 89, 6: 129, 7: 55, 8: 1406, 9: 361}
# 2018-06-23 16:02:09,273 - framestack - INFO: steps: 7771680, steps/s: 93.98
#   epoch reward:       3.0624/8.3974/15.2427 [n=10] (min/mean/max)
#   running reward:     0.4673/9.7120/30.8297 [n=500]
#
# 2018-06-23 16:02:56,348 - framestack - INFO: action counts: {0: 226, 1: 50, 2: 920, 3: 33, 4: 1048, 5: 82, 6: 118, 7: 55, 8: 1417, 9: 371}
# 2018-06-23 16:02:56,377 - framestack - INFO: steps: 7776000, steps/s: 93.97
#   epoch reward:       3.0624/11.1379/27.9336 [n=10] (min/mean/max)
#   running reward:     0.4673/9.6995/30.8297 [n=500]
#
# 2018-06-23 16:03:43,428 - framestack - INFO: action counts: {0: 234, 1: 48, 2: 948, 3: 32, 4: 980, 5: 76, 6: 128, 7: 54, 8: 1441, 9: 379}
# 2018-06-23 16:03:43,453 - framestack - INFO: steps: 7780320, steps/s: 93.96
#   epoch reward:       3.0624/12.2642/27.9336 [n=10] (min/mean/max)
#   running reward:     0.4673/9.7106/30.8297 [n=500]
#
# 2018-06-23 16:04:32,699 - framestack - INFO: action counts: {0: 228, 1: 40, 2: 898, 3: 32, 4: 1009, 5: 91, 6: 132, 7: 61, 8: 1455, 9: 374}
# 2018-06-23 16:04:32,723 - framestack - INFO: steps: 7784640, steps/s: 93.95
#   epoch reward:       3.0624/14.0190/27.9336 [n=10] (min/mean/max)
#   running reward:     0.4673/9.7512/30.8297 [n=500]
#
# 2018-06-23 16:05:18,790 - framestack - INFO: action counts: {0: 215, 1: 43, 2: 930, 3: 35, 4: 1045, 5: 101, 6: 116, 7: 53, 8: 1392, 9: 390}
# 2018-06-23 16:05:18,816 - framestack - INFO: steps: 7788960, steps/s: 93.95
#   epoch reward:       6.3167/18.4685/47.0356 [n=10] (min/mean/max)
#   running reward:     0.4673/9.8551/47.0356 [n=500]
#
# 2018-06-23 16:06:04,751 - framestack - INFO: action counts: {0: 199, 1: 36, 2: 895, 3: 30, 4: 1048, 5: 93, 6: 111, 7: 50, 8: 1469, 9: 389}
# 2018-06-23 16:06:04,777 - framestack - INFO: steps: 7793280, steps/s: 93.95
#   epoch reward:       2.1648/17.2483/47.0356 [n=10] (min/mean/max)
#   running reward:     0.4673/9.9345/47.0356 [n=500]
#
# 2018-06-23 16:06:52,430 - framestack - INFO: action counts: {0: 239, 1: 40, 2: 924, 3: 35, 4: 1024, 5: 99, 6: 107, 7: 67, 8: 1362, 9: 423}
# 2018-06-23 16:06:52,455 - framestack - INFO: steps: 7797600, steps/s: 93.94
#   epoch reward:       2.1648/15.5674/47.0356 [n=10] (min/mean/max)
#   running reward:     0.4673/9.9804/47.0356 [n=500]
#
# 2018-06-23 16:07:39,184 - framestack - INFO: action counts: {0: 230, 1: 49, 2: 903, 3: 38, 4: 960, 5: 103, 6: 146, 7: 73, 8: 1394, 9: 424}
# 2018-06-23 16:07:39,211 - framestack - INFO: steps: 7801920, steps/s: 93.94
#   epoch reward:       0.1048/14.6245/47.0356 [n=10] (min/mean/max)
#   running reward:     0.1048/10.0684/47.0356 [n=500]
#
# 2018-06-23 16:08:24,634 - framestack - INFO: action counts: {0: 252, 1: 46, 2: 908, 3: 30, 4: 1019, 5: 111, 6: 113, 7: 70, 8: 1383, 9: 388}
# 2018-06-23 16:08:24,656 - framestack - INFO: steps: 7806240, steps/s: 93.94
#   epoch reward:       0.1048/14.2573/47.0356 [n=10] (min/mean/max)
#   running reward:     0.1048/10.1787/47.0356 [n=500]
#
# 2018-06-23 16:09:12,340 - framestack - INFO: action counts: {0: 240, 1: 42, 2: 931, 3: 45, 4: 1022, 5: 110, 6: 118, 7: 65, 8: 1349, 9: 398}
# 2018-06-23 16:09:12,370 - framestack - INFO: steps: 7810560, steps/s: 93.93
#   epoch reward:       0.1048/15.9596/47.0356 [n=10] (min/mean/max)
#   running reward:     0.1048/10.3341/47.0356 [n=500]
#
# 2018-06-23 16:09:59,092 - framestack - INFO: action counts: {0: 255, 1: 45, 2: 902, 3: 46, 4: 940, 5: 110, 6: 159, 7: 83, 8: 1362, 9: 418}
# 2018-06-23 16:09:59,121 - framestack - INFO: steps: 7814880, steps/s: 93.93
#   epoch reward:       0.1048/14.5940/47.0356 [n=10] (min/mean/max)
#   running reward:     0.1048/10.3876/47.0356 [n=500]
#
# 2018-06-23 16:10:43,348 - framestack - INFO: action counts: {0: 214, 1: 32, 2: 890, 3: 40, 4: 1000, 5: 113, 6: 131, 7: 45, 8: 1437, 9: 418}
# 2018-06-23 16:10:43,377 - framestack - INFO: steps: 7819200, steps/s: 93.93
#   epoch reward:       0.1048/14.9163/47.0356 [n=10] (min/mean/max)
#   running reward:     0.1048/10.4601/47.0356 [n=500]
#
# 2018-06-23 16:11:28,708 - framestack - INFO: action counts: {0: 239, 1: 54, 2: 888, 3: 41, 4: 1017, 5: 92, 6: 122, 7: 68, 8: 1399, 9: 400}
# 2018-06-23 16:11:28,733 - framestack - INFO: steps: 7823520, steps/s: 93.93
#   epoch reward:       0.1048/14.9163/47.0356 [n=10] (min/mean/max)
#   running reward:     0.1048/10.5396/47.0356 [n=500]
#
# 2018-06-23 16:12:15,558 - framestack - INFO: action counts: {0: 272, 1: 53, 2: 901, 3: 38, 4: 986, 5: 118, 6: 134, 7: 54, 8: 1367, 9: 397}
# 2018-06-23 16:12:15,583 - framestack - INFO: steps: 7827840, steps/s: 93.93
#   epoch reward:       0.1048/8.8639/18.2515 [n=10] (min/mean/max)
#   running reward:     0.1048/10.4980/47.0356 [n=500]
#
# 2018-06-23 16:13:00,232 - framestack - INFO: action counts: {0: 252, 1: 52, 2: 886, 3: 38, 4: 958, 5: 121, 6: 140, 7: 88, 8: 1375, 9: 410}
# 2018-06-23 16:13:00,258 - framestack - INFO: steps: 7832160, steps/s: 93.94
#   epoch reward:       0.1048/9.4303/18.2515 [n=10] (min/mean/max)
#   running reward:     0.1048/10.4254/47.0356 [n=500]
#
# 2018-06-23 16:13:45,159 - framestack - INFO: action counts: {0: 270, 1: 58, 2: 902, 3: 38, 4: 994, 5: 123, 6: 153, 7: 84, 8: 1298, 9: 400}
# 2018-06-23 16:13:45,184 - framestack - INFO: steps: 7836480, steps/s: 93.95
#   epoch reward:       0.1048/8.8638/18.2515 [n=10] (min/mean/max)
#   running reward:     0.1048/10.3414/47.0356 [n=500]
#
# 2018-06-23 16:14:30,379 - framestack - INFO: action counts: {0: 240, 1: 56, 2: 919, 3: 43, 4: 986, 5: 101, 6: 151, 7: 69, 8: 1378, 9: 377}
# 2018-06-23 16:14:30,407 - framestack - INFO: steps: 7840800, steps/s: 93.96
#   epoch reward:       3.2849/11.5163/26.6303 [n=10] (min/mean/max)
#   running reward:     0.1048/10.3333/47.0356 [n=500]
#
# 2018-06-23 16:15:14,728 - framestack - INFO: action counts: {0: 241, 1: 46, 2: 893, 3: 37, 4: 1010, 5: 103, 6: 132, 7: 60, 8: 1424, 9: 374}
# 2018-06-23 16:15:14,755 - framestack - INFO: steps: 7845120, steps/s: 93.96
#   epoch reward:       2.5548/9.1088/18.2515 [n=10] (min/mean/max)
#   running reward:     0.1048/10.2963/47.0356 [n=500]
#
# 2018-06-23 16:15:59,538 - framestack - INFO: action counts: {0: 251, 1: 45, 2: 837, 3: 29, 4: 1039, 5: 108, 6: 138, 7: 61, 8: 1432, 9: 380}
# 2018-06-23 16:15:59,563 - framestack - INFO: steps: 7849440, steps/s: 93.97
#   epoch reward:       2.5548/9.2525/15.2427 [n=10] (min/mean/max)
#   running reward:     0.1048/10.2506/47.0356 [n=500]
#
# 2018-06-23 16:16:43,778 - framestack - INFO: action counts: {0: 207, 1: 41, 2: 971, 3: 40, 4: 967, 5: 109, 6: 136, 7: 53, 8: 1407, 9: 389}
# 2018-06-23 16:16:43,810 - framestack - INFO: steps: 7853760, steps/s: 93.98
#   epoch reward:       2.5548/11.1358/28.4084 [n=10] (min/mean/max)
#   running reward:     0.1048/10.2360/47.0356 [n=500]
#
# 2018-06-23 16:17:28,093 - framestack - INFO: action counts: {0: 222, 1: 43, 2: 964, 3: 25, 4: 974, 5: 104, 6: 113, 7: 70, 8: 1424, 9: 381}
# 2018-06-23 16:17:28,118 - framestack - INFO: steps: 7858080, steps/s: 93.99
#   epoch reward:       2.5548/11.2181/28.4084 [n=10] (min/mean/max)
#   running reward:     0.1048/10.2600/47.0356 [n=500]
#
# 2018-06-23 16:18:12,816 - framestack - INFO: action counts: {0: 207, 1: 52, 2: 977, 3: 37, 4: 1026, 5: 100, 6: 117, 7: 50, 8: 1366, 9: 388}
# 2018-06-23 16:18:12,840 - framestack - INFO: steps: 7862400, steps/s: 94.00
#   epoch reward:       2.5548/11.2181/28.4084 [n=10] (min/mean/max)
#   running reward:     0.1048/10.2806/47.0356 [n=500]
#
# 2018-06-23 16:18:55,717 - framestack - INFO: action counts: {0: 207, 1: 34, 2: 908, 3: 39, 4: 1042, 5: 101, 6: 117, 7: 46, 8: 1420, 9: 406}
# 2018-06-23 16:18:55,742 - framestack - INFO: steps: 7866720, steps/s: 94.02
#   epoch reward:       2.5548/11.0461/28.4084 [n=10] (min/mean/max)
#   running reward:     0.1048/10.2978/47.0356 [n=500]
#
# 2018-06-23 16:19:40,182 - framestack - INFO: action counts: {0: 230, 1: 52, 2: 888, 3: 44, 4: 1017, 5: 99, 6: 145, 7: 68, 8: 1389, 9: 388}
# 2018-06-23 16:19:40,211 - framestack - INFO: steps: 7871040, steps/s: 94.03
#   epoch reward:       2.5548/10.3255/28.4084 [n=10] (min/mean/max)
#   running reward:     0.1048/10.3434/47.0356 [n=500]
# saving ./outputs/RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack/PPO_512z_all_g.pkl
# saving backup ./outputs/RNN_v3b_128im_512z_1512_v6k_VAE5_all_noframestack/PPO_512z_all_g-20180623_08-20-24.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-81e0dd8adde3> in <module>()
#       1 try:
# ----> 2     run_iterations(agent, log_dir=log_dir)
#       3 except KeyboardInterrupt:
#       4     # Close the environment
#       5     if config.num_workers == 1:
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/helpers/deep_rl/utils.py in run_iterations(agent, log_dir)
#      22     while True:
#      23         steps0 = agent.total_steps
# ---> 24         agent.iteration()
#      25         history['steps'].append(agent.total_steps - steps0)
#      26         history['rewards'] += agent.last_episode_rewards.tolist()
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/helpers/deep_rl/ppo_agent.py in iteration(self)
#      68         for _ in range(config.rollout_length):
#      69             with torch.no_grad():
# ---> 70                 actions, log_probs, _, values, next_hidden_states = self.network.predict(z_states, hidden_states=hidden_states)
#      71             next_states, rewards, terminals, _ = self.task.step(actions.cpu().detach().numpy())
#      72             self.episode_rewards += rewards
#
# /media/oldhome/wassname/Documents/projects/retro_sonic_comp/world-models-pytorch/world_models_sonic/helpers/deep_rl/network_heads.py in predict(self, obs_z, action, next_obs_z, hidden_states)
#     159             self.render()
#     160
# --> 161         self.world_model.train()
#     162
#     163         return action, log_prob, entropy, value, hidden_states
#
# ~/.pyenv/versions/3.5.3/envs/jupyter3/lib/python3.5/site-packages/torch/nn/modules/module.py in train(self, mode)
#     883         self.training = mode
#     884         for module in self.children():
# --> 885             module.train(mode)
#     886         return self
#     887
#
# ~/.pyenv/versions/3.5.3/envs/jupyter3/lib/python3.5/site-packages/torch/nn/modules/module.py in train(self, mode)
#     883         self.training = mode
#     884         for module in self.children():
# --> 885             module.train(mode)
#     886         return self
#     887
#
# ~/.pyenv/versions/3.5.3/envs/jupyter3/lib/python3.5/site-packages/torch/nn/modules/module.py in train(self, mode)
#     883         self.training = mode
#     884         for module in self.children():
# --> 885             module.train(mode)
#     886         return self
#     887
#
# ~/.pyenv/versions/3.5.3/envs/jupyter3/lib/python3.5/site-packages/torch/nn/modules/module.py in train(self, mode)
#     881             Module: self
#     882         """
# --> 883         self.training = mode
#     884         for module in self.children():
#     885             module.train(mode)
#
# KeyboardInterrupt:

# %% [markdown]
#     2018-06-20 09:40:21,906 - framestack - INFO: action counts: {0: 127, 1: 41, 2: 196, 3: 22, 4: 185, 5: 96, 6: 97, 7: 35, 8: 238, 9: 83}
#     2018-06-20 09:40:21,928 - framestack - INFO: steps: 23520, steps/s: 47.68
#       world model losses: 40.4108 rnn=26.8570, inv= 0.1192=0.0050 * 23.8446, vae=13.4345=0.1250 * (93.5157 + 0.0833 * 167.5278)
#       epoch reward:       0.0000/1.2111/12.7297 [n=40] (min/mean/max)
#       running reward:     0.0000/0.9334/12.7297 [n=500]
#
#     2018-06-21 07:12:46,362 - framestack - INFO: action counts: {0: 82, 1: 20, 2: 252, 3: 19, 4: 217, 5: 61, 6: 129, 7: 48, 8: 224, 9: 68}
#     2018-06-21 07:12:46,379 - framestack - INFO: steps: 3764320, steps/s: 48.60
#       world model losses: 34.7660 rnn=24.8725, inv= 0.0004=0.0050 * 0.0753, vae=9.8931=0.1250 * (63.7831 + 0.0833 * 184.3440)
#       epoch reward:       0.7183/10.4729/38.4701 [n=40] (min/mean/max)
#       running reward:     0.7183/10.6002/38.4701 [n=500]

# %%
agent.save(ppo_save_file)
torch.save(config.intrinsic_reward_normalizer.state_dict(), ppo_save_file.replace('.pkl', '-intrinsic_reward_normalizer.pkl'))
torch.save(config.reward_normalizer.state_dict(), ppo_save_file.replace('.pkl', '-reward_normalizer.pkl'))

# %%
agent.save(ppo_save_file)
# torch.save(config.intrinsic_reward_normalizer.state_dict(), ppo_save_file.replace('.pkl', '-intrinsic_reward_normalizer.pkl'))
# torch.save(config.reward_normalizer.state_dict(), ppo_save_file.replace('.pkl', '-reward_normalizer.pkl'))

# %% [markdown]
# # Summarize model

# %%
agent.network.world_model.mdnrnn.training

# %%
from IPython.display import display

with torch.no_grad():
    img = np.random.randn(image_size, image_size, 3)
    action = np.array(np.random.randint(0,action_dim))[np.newaxis]
    action = Variable(torch.from_numpy(action)).float().cuda()[np.newaxis]
    gpu_img = Variable(torch.from_numpy(img[np.newaxis].transpose(0, 3, 1, 2))).float().cuda()
    if cuda:
        gpu_img = gpu_img.cuda()
    with TorchSummarizeDf(vae) as tdf:
        x, mu_vae, logvar_vae = vae.forward(gpu_img)
        z = vae.sample(mu_vae, logvar_vae)
        df_vae = tdf.make_df()

    display(df_vae[df_vae.level<2])
    
    with TorchSummarizeDf(mdnrnn) as tdf: 
        pi, mu, sigma, hidden_state = mdnrnn.forward(z.unsqueeze(1).repeat((1,2,1)))
        z_next = mdnrnn.sample(pi, mu, sigma)
        df_mdnrnn = tdf.make_df()
    
    display(df_mdnrnn)
    

    with TorchSummarizeDf(finv) as tdf:
        finv(z.repeat((1,2,1)), z_next)   
        df_finv = tdf.make_df()
    display(df_finv)

    with TorchSummarizeDf(world_model) as tdf:
        world_model(gpu_img, action)
        df_world_model = tdf.make_df()
    display(df_world_model[df_world_model.level<2])
    
    del img, action, gpu_img, x, mu, z, z_next, mu_vae, pi, sigma, logvar_vae
